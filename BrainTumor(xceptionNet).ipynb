# %% [markdown]
# <a href="https://colab.research.google.com/github/nafi-rahman/Comparative-Study-of-various-techniques-using-Deep-Learning-for-Brain-Tumor-Detection/blob/main/BrainTumor(xceptionNet).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import cv2
from imgaug import augmenters as iaa
import os
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from keras.utils import to_categorical
from keras.applications import resnet
from tensorflow.keras.applications import VGG16, ResNet50, ResNet101, InceptionResNetV2
from tensorflow.keras.layers import AveragePooling2D
from tensorflow.keras.layers import Dropout
from tensorflow.keras.layers import Flatten
from tensorflow.keras.layers import Dense
from tensorflow.keras.layers import Input
from tensorflow.keras.models import Model
from tensorflow.keras.optimizers import Adam, SGD
from tensorflow.keras.utils import to_categorical
from sklearn.preprocessing import LabelBinarizer
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix
from imutils import paths
import matplotlib.pyplot as plt
import numpy as np
import argparse
import cv2
import os
from keras import Sequential
from keras.layers import Dense, GlobalAveragePooling2D, Dropout, BatchNormalization
from keras.callbacks import EarlyStopping, ModelCheckpoint

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
from PIL import Image
from tensorflow.keras.preprocessing.image import ImageDataGenerator
import os

img_rows, img_cols = 224, 224

isolated_train_path = "/content/drive/MyDrive/Database/BrainTumor(10K_new)/Training"
isolated_test_path = "/content/drive/MyDrive/Database/BrainTumor(10K_new)/Testing"

for root, dirnames, filenames in os.walk(isolated_train_path):
    for filename in filenames:
        file_path = os.path.join(root, filename)
        img = Image.open(file_path)
        grey = img.resize((img_rows, img_cols))
        grey.save(file_path)

train_data_dir = isolated_train_path
validation_data_dir = isolated_test_path

img_width, img_height, channel = img_rows, img_cols, 3
batch_size = 20

# Data augmentation settings
train_datagen = ImageDataGenerator(
    rescale=1.0/255.0,
    rotation_range=20,  # Rotate images randomly up to 20 degrees
    width_shift_range=0.2,  # Shift the width of the image randomly
    height_shift_range=0.2,  # Shift the height of the image randomly
    shear_range=0.2,  # Apply shear transformation randomly
    zoom_range=0.2,  # Zoom in/out randomly
    horizontal_flip=True,  # Flip images horizontally
    fill_mode='nearest'  # Fill newly created pixels after rotation or shift
)

validation_datagen = ImageDataGenerator(rescale=1./244)  # Only rescale for validation data

# Automatically retrieve images and their classes for training and validation
train_generator = train_datagen.flow_from_directory(
    train_data_dir,
    target_size=(img_width, img_height),
    batch_size=batch_size,
    shuffle=True,
    class_mode='categorical'
)

validation_generator = validation_datagen.flow_from_directory(
    validation_data_dir,
    target_size=(img_width, img_height),
    batch_size=batch_size,
    shuffle=False,
    class_mode='categorical'
)

IMG_SHAPE = img_cols, img_rows, 3
classes = 4

num_epoch = 30
num_train_samples = train_generator.samples
num_validation_samples = validation_generator.samples

print('num_train_samples:', num_train_samples)
print('num_validation_samples:', num_validation_samples)
# Out:
# Found 8000 images belonging to 4 classes.
# Found 2000 images belonging to 4 classes.
# num_train_samples: 8000
# num_validation_samples: 2000

# %%
class_names = list(train_generator.class_indices.keys())
print(class_names)

class_names = list(validation_generator.class_indices.keys())
print(class_names)

print(train_generator.class_indices)
print(validation_generator.class_indices)
# Out:
# ['glioma', 'meningioma', 'notumor', 'pituitary']
# ['glioma', 'meningioma', 'notumor', 'pituitary']
# {'glioma': 0, 'meningioma': 1, 'notumor': 2, 'pituitary': 3}
# {'glioma': 0, 'meningioma': 1, 'notumor': 2, 'pituitary': 3}

# %%
import matplotlib.pyplot as plt
import numpy as np

# Get true labels
y_train_true = train_generator.classes

# Count samples per class
unique_classes, class_counts = np.unique(y_train_true, return_counts=True)
for class_label, count in zip(unique_classes, class_counts):
    print("Class {}: {} samples".format(class_label, count))


# Plot class distribution
plt.bar(unique_classes, class_counts)
plt.xlabel('Class')
plt.ylabel('Number of Samples')
plt.title('Class Distribution')
plt.show()
# Out:
# Class 0: 2000 samples
# Class 1: 2000 samples
# Class 2: 2000 samples
# Class 3: 2000 samples

# %%
#xceptionNet

from tensorflow.keras import layers, models

def xception(input_shape, num_classes):
    def entry_flow(x):
        x = layers.Conv2D(32, (3, 3), strides=(2, 2), padding='same')(x)
        x = layers.BatchNormalization()(x)
        x = layers.Activation('relu')(x)

        x = layers.Conv2D(64, (3, 3), padding='same')(x)
        x = layers.BatchNormalization()(x)
        x = layers.Activation('relu')(x)

        previous_block_activation = x

        for filters in [128, 256, 728]:
            x = layers.Activation('relu')(x)
            x = layers.SeparableConv2D(filters, (3, 3), padding='same')(x)
            x = layers.BatchNormalization()(x)

            x = layers.Activation('relu')(x)
            x = layers.SeparableConv2D(filters, (3, 3), padding='same')(x)
            x = layers.BatchNormalization()(x)

            x = layers.MaxPooling2D((3, 3), strides=(2, 2), padding='same')(x)

            residual = layers.Conv2D(filters, (1, 1), strides=(2, 2), padding='same')(previous_block_activation)
            x = layers.add([x, residual])
            previous_block_activation = x

        return x

    def middle_flow(x, num_blocks=8):
        for _ in range(num_blocks):
            previous_block_activation = x

            x = layers.Activation('relu')(x)
            x = layers.SeparableConv2D(728, (3, 3), padding='same')(x)
            x = layers.BatchNormalization()(x)

            x = layers.Activation('relu')(x)
            x = layers.SeparableConv2D(728, (3, 3), padding='same')(x)
            x = layers.BatchNormalization()(x)

            x = layers.Activation('relu')(x)
            x = layers.SeparableConv2D(728, (3, 3), padding='same')(x)
            x = layers.BatchNormalization()(x)

            x = layers.add([x, previous_block_activation])

        return x

    def exit_flow(x):
        previous_block_activation = x

        x = layers.Activation('relu')(x)
        x = layers.SeparableConv2D(728, (3, 3), padding='same')(x)
        x = layers.BatchNormalization()(x)

        x = layers.Activation('relu')(x)
        x = layers.SeparableConv2D(1024, (3, 3), padding='same')(x)
        x = layers.BatchNormalization()(x)

        x = layers.MaxPooling2D((3, 3), strides=(2, 2), padding='same')(x)

        residual = layers.Conv2D(1024, (1, 1), strides=(2, 2), padding='same')(previous_block_activation)
        x = layers.add([x, residual])

        x = layers.SeparableConv2D(1536, (3, 3), padding='same')(x)
        x = layers.BatchNormalization()(x)
        x = layers.Activation('relu')(x)

        x = layers.SeparableConv2D(2048, (3, 3), padding='same')(x)
        x = layers.BatchNormalization()(x)
        x = layers.Activation('relu')(x)

        x = layers.GlobalAveragePooling2D()(x)

        return x

    # Define model
    inputs = layers.Input(shape=input_shape)
    x = entry_flow(inputs)
    x = middle_flow(x)
    x = exit_flow(x)
    outputs = layers.Dense(num_classes, activation='softmax')(x)

    model = models.Model(inputs, outputs)
    return model

# Define model
input_shape = (224, 224, 3)
num_classes = 4
model = xception(input_shape, num_classes)

# Compile model
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])


# Print model summary
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 224, 224, 3  0           []
#                                 )]
#
#  conv2d (Conv2D)                (None, 112, 112, 32  896         ['input_1[0][0]']
#                                 )
#
#  batch_normalization (BatchNorm  (None, 112, 112, 32  128        ['conv2d[0][0]']
#  alization)                     )
#
#  activation (Activation)        (None, 112, 112, 32  0           ['batch_normalization[0][0]']
#                                 )
#
#  conv2d_1 (Conv2D)              (None, 112, 112, 64  18496       ['activation[0][0]']
#                                 )
#
#  batch_normalization_1 (BatchNo  (None, 112, 112, 64  256        ['conv2d_1[0][0]']
#  rmalization)                   )
#
#  activation_1 (Activation)      (None, 112, 112, 64  0           ['batch_normalization_1[0][0]']
#                                 )
#
#  activation_2 (Activation)      (None, 112, 112, 64  0           ['activation_1[0][0]']
#                                 )
#
#  separable_conv2d (SeparableCon  (None, 112, 112, 12  8896       ['activation_2[0][0]']
#  v2D)                           8)
#
#  batch_normalization_2 (BatchNo  (None, 112, 112, 12  512        ['separable_conv2d[0][0]']
#  rmalization)                   8)
#
#  activation_3 (Activation)      (None, 112, 112, 12  0           ['batch_normalization_2[0][0]']
#                                 8)
#
#  separable_conv2d_1 (SeparableC  (None, 112, 112, 12  17664      ['activation_3[0][0]']
#  onv2D)                         8)
#
#  batch_normalization_3 (BatchNo  (None, 112, 112, 12  512        ['separable_conv2d_1[0][0]']
#  rmalization)                   8)
#
#  max_pooling2d (MaxPooling2D)   (None, 56, 56, 128)  0           ['batch_normalization_3[0][0]']
#
#  conv2d_2 (Conv2D)              (None, 56, 56, 128)  8320        ['activation_1[0][0]']
#
#  add (Add)                      (None, 56, 56, 128)  0           ['max_pooling2d[0][0]',
#                                                                   'conv2d_2[0][0]']
#
#  activation_4 (Activation)      (None, 56, 56, 128)  0           ['add[0][0]']
#
#  separable_conv2d_2 (SeparableC  (None, 56, 56, 256)  34176      ['activation_4[0][0]']
#  onv2D)
#
#  batch_normalization_4 (BatchNo  (None, 56, 56, 256)  1024       ['separable_conv2d_2[0][0]']
#  rmalization)
#
#  activation_5 (Activation)      (None, 56, 56, 256)  0           ['batch_normalization_4[0][0]']
#
#  separable_conv2d_3 (SeparableC  (None, 56, 56, 256)  68096      ['activation_5[0][0]']
#  onv2D)
#
#  batch_normalization_5 (BatchNo  (None, 56, 56, 256)  1024       ['separable_conv2d_3[0][0]']
#  rmalization)
#
#  max_pooling2d_1 (MaxPooling2D)  (None, 28, 28, 256)  0          ['batch_normalization_5[0][0]']
#
#  conv2d_3 (Conv2D)              (None, 28, 28, 256)  33024       ['add[0][0]']
#
#  add_1 (Add)                    (None, 28, 28, 256)  0           ['max_pooling2d_1[0][0]',
#                                                                   'conv2d_3[0][0]']
#
#  activation_6 (Activation)      (None, 28, 28, 256)  0           ['add_1[0][0]']
#
#  separable_conv2d_4 (SeparableC  (None, 28, 28, 728)  189400     ['activation_6[0][0]']
#  onv2D)
#
#  batch_normalization_6 (BatchNo  (None, 28, 28, 728)  2912       ['separable_conv2d_4[0][0]']
#  rmalization)
#
#  activation_7 (Activation)      (None, 28, 28, 728)  0           ['batch_normalization_6[0][0]']
#
#  separable_conv2d_5 (SeparableC  (None, 28, 28, 728)  537264     ['activation_7[0][0]']
#  onv2D)
#
#  batch_normalization_7 (BatchNo  (None, 28, 28, 728)  2912       ['separable_conv2d_5[0][0]']
#  rmalization)
#
#  max_pooling2d_2 (MaxPooling2D)  (None, 14, 14, 728)  0          ['batch_normalization_7[0][0]']
#
#  conv2d_4 (Conv2D)              (None, 14, 14, 728)  187096      ['add_1[0][0]']
#
#  add_2 (Add)                    (None, 14, 14, 728)  0           ['max_pooling2d_2[0][0]',
#                                                                   'conv2d_4[0][0]']
#
#  activation_8 (Activation)      (None, 14, 14, 728)  0           ['add_2[0][0]']
#
#  separable_conv2d_6 (SeparableC  (None, 14, 14, 728)  537264     ['activation_8[0][0]']
#  onv2D)
#
#  batch_normalization_8 (BatchNo  (None, 14, 14, 728)  2912       ['separable_conv2d_6[0][0]']
#  rmalization)
#
#  activation_9 (Activation)      (None, 14, 14, 728)  0           ['batch_normalization_8[0][0]']
#
#  separable_conv2d_7 (SeparableC  (None, 14, 14, 728)  537264     ['activation_9[0][0]']
#  onv2D)
#
#  batch_normalization_9 (BatchNo  (None, 14, 14, 728)  2912       ['separable_conv2d_7[0][0]']
#  rmalization)
#
#  activation_10 (Activation)     (None, 14, 14, 728)  0           ['batch_normalization_9[0][0]']
#
#  separable_conv2d_8 (SeparableC  (None, 14, 14, 728)  537264     ['activation_10[0][0]']
#  onv2D)
#
#  batch_normalization_10 (BatchN  (None, 14, 14, 728)  2912       ['separable_conv2d_8[0][0]']
#  ormalization)
#
#  add_3 (Add)                    (None, 14, 14, 728)  0           ['batch_normalization_10[0][0]',
#                                                                   'add_2[0][0]']
#
#  activation_11 (Activation)     (None, 14, 14, 728)  0           ['add_3[0][0]']
#
#  separable_conv2d_9 (SeparableC  (None, 14, 14, 728)  537264     ['activation_11[0][0]']
#  onv2D)
#
#  batch_normalization_11 (BatchN  (None, 14, 14, 728)  2912       ['separable_conv2d_9[0][0]']
#  ormalization)
#
#  activation_12 (Activation)     (None, 14, 14, 728)  0           ['batch_normalization_11[0][0]']
#
#  separable_conv2d_10 (Separable  (None, 14, 14, 728)  537264     ['activation_12[0][0]']
#  Conv2D)
#
#  batch_normalization_12 (BatchN  (None, 14, 14, 728)  2912       ['separable_conv2d_10[0][0]']
#  ormalization)
#
#  activation_13 (Activation)     (None, 14, 14, 728)  0           ['batch_normalization_12[0][0]']
#
#  separable_conv2d_11 (Separable  (None, 14, 14, 728)  537264     ['activation_13[0][0]']
#  Conv2D)
#
#  batch_normalization_13 (BatchN  (None, 14, 14, 728)  2912       ['separable_conv2d_11[0][0]']
#  ormalization)
#
#  add_4 (Add)                    (None, 14, 14, 728)  0           ['batch_normalization_13[0][0]',
#                                                                   'add_3[0][0]']
#
#  activation_14 (Activation)     (None, 14, 14, 728)  0           ['add_4[0][0]']
#
#  separable_conv2d_12 (Separable  (None, 14, 14, 728)  537264     ['activation_14[0][0]']
#  Conv2D)
#
#  batch_normalization_14 (BatchN  (None, 14, 14, 728)  2912       ['separable_conv2d_12[0][0]']
#  ormalization)
#
#  activation_15 (Activation)     (None, 14, 14, 728)  0           ['batch_normalization_14[0][0]']
#
#  separable_conv2d_13 (Separable  (None, 14, 14, 728)  537264     ['activation_15[0][0]']
#  Conv2D)
#
#  batch_normalization_15 (BatchN  (None, 14, 14, 728)  2912       ['separable_conv2d_13[0][0]']
#  ormalization)
#
#  activation_16 (Activation)     (None, 14, 14, 728)  0           ['batch_normalization_15[0][0]']
#
#  separable_conv2d_14 (Separable  (None, 14, 14, 728)  537264     ['activation_16[0][0]']
#  Conv2D)
#
#  batch_normalization_16 (BatchN  (None, 14, 14, 728)  2912       ['separable_conv2d_14[0][0]']
#  ormalization)
#
#  add_5 (Add)                    (None, 14, 14, 728)  0           ['batch_normalization_16[0][0]',
#                                                                   'add_4[0][0]']
#
#  activation_17 (Activation)     (None, 14, 14, 728)  0           ['add_5[0][0]']
#
#  separable_conv2d_15 (Separable  (None, 14, 14, 728)  537264     ['activation_17[0][0]']
#  Conv2D)
#
#  batch_normalization_17 (BatchN  (None, 14, 14, 728)  2912       ['separable_conv2d_15[0][0]']
#  ormalization)
#
#  activation_18 (Activation)     (None, 14, 14, 728)  0           ['batch_normalization_17[0][0]']
#
#  separable_conv2d_16 (Separable  (None, 14, 14, 728)  537264     ['activation_18[0][0]']
#  Conv2D)
#
#  batch_normalization_18 (BatchN  (None, 14, 14, 728)  2912       ['separable_conv2d_16[0][0]']
#  ormalization)
#
#  activation_19 (Activation)     (None, 14, 14, 728)  0           ['batch_normalization_18[0][0]']
#
#  separable_conv2d_17 (Separable  (None, 14, 14, 728)  537264     ['activation_19[0][0]']
#  Conv2D)
#
#  batch_normalization_19 (BatchN  (None, 14, 14, 728)  2912       ['separable_conv2d_17[0][0]']
#  ormalization)
#
#  add_6 (Add)                    (None, 14, 14, 728)  0           ['batch_normalization_19[0][0]',
#                                                                   'add_5[0][0]']
#
#  activation_20 (Activation)     (None, 14, 14, 728)  0           ['add_6[0][0]']
#
#  separable_conv2d_18 (Separable  (None, 14, 14, 728)  537264     ['activation_20[0][0]']
#  Conv2D)
#
#  batch_normalization_20 (BatchN  (None, 14, 14, 728)  2912       ['separable_conv2d_18[0][0]']
#  ormalization)
#
#  activation_21 (Activation)     (None, 14, 14, 728)  0           ['batch_normalization_20[0][0]']
#
#  separable_conv2d_19 (Separable  (None, 14, 14, 728)  537264     ['activation_21[0][0]']
#  Conv2D)
#
#  batch_normalization_21 (BatchN  (None, 14, 14, 728)  2912       ['separable_conv2d_19[0][0]']
#  ormalization)
#
#  activation_22 (Activation)     (None, 14, 14, 728)  0           ['batch_normalization_21[0][0]']
#
#  separable_conv2d_20 (Separable  (None, 14, 14, 728)  537264     ['activation_22[0][0]']
#  Conv2D)
#
#  batch_normalization_22 (BatchN  (None, 14, 14, 728)  2912       ['separable_conv2d_20[0][0]']
#  ormalization)
#
#  add_7 (Add)                    (None, 14, 14, 728)  0           ['batch_normalization_22[0][0]',
#                                                                   'add_6[0][0]']
#
#  activation_23 (Activation)     (None, 14, 14, 728)  0           ['add_7[0][0]']
#
#  separable_conv2d_21 (Separable  (None, 14, 14, 728)  537264     ['activation_23[0][0]']
#  Conv2D)
#
#  batch_normalization_23 (BatchN  (None, 14, 14, 728)  2912       ['separable_conv2d_21[0][0]']
#  ormalization)
#
#  activation_24 (Activation)     (None, 14, 14, 728)  0           ['batch_normalization_23[0][0]']
#
#  separable_conv2d_22 (Separable  (None, 14, 14, 728)  537264     ['activation_24[0][0]']
#  Conv2D)
#
#  batch_normalization_24 (BatchN  (None, 14, 14, 728)  2912       ['separable_conv2d_22[0][0]']
#  ormalization)
#
#  activation_25 (Activation)     (None, 14, 14, 728)  0           ['batch_normalization_24[0][0]']
#
#  separable_conv2d_23 (Separable  (None, 14, 14, 728)  537264     ['activation_25[0][0]']
#  Conv2D)
#
#  batch_normalization_25 (BatchN  (None, 14, 14, 728)  2912       ['separable_conv2d_23[0][0]']
#  ormalization)
#
#  add_8 (Add)                    (None, 14, 14, 728)  0           ['batch_normalization_25[0][0]',
#                                                                   'add_7[0][0]']
#
#  activation_26 (Activation)     (None, 14, 14, 728)  0           ['add_8[0][0]']
#
#  separable_conv2d_24 (Separable  (None, 14, 14, 728)  537264     ['activation_26[0][0]']
#  Conv2D)
#
#  batch_normalization_26 (BatchN  (None, 14, 14, 728)  2912       ['separable_conv2d_24[0][0]']
#  ormalization)
#
#  activation_27 (Activation)     (None, 14, 14, 728)  0           ['batch_normalization_26[0][0]']
#
#  separable_conv2d_25 (Separable  (None, 14, 14, 728)  537264     ['activation_27[0][0]']
#  Conv2D)
#
#  batch_normalization_27 (BatchN  (None, 14, 14, 728)  2912       ['separable_conv2d_25[0][0]']
#  ormalization)
#
#  activation_28 (Activation)     (None, 14, 14, 728)  0           ['batch_normalization_27[0][0]']
#
#  separable_conv2d_26 (Separable  (None, 14, 14, 728)  537264     ['activation_28[0][0]']
#  Conv2D)
#
#  batch_normalization_28 (BatchN  (None, 14, 14, 728)  2912       ['separable_conv2d_26[0][0]']
#  ormalization)
#
#  add_9 (Add)                    (None, 14, 14, 728)  0           ['batch_normalization_28[0][0]',
#                                                                   'add_8[0][0]']
#
#  activation_29 (Activation)     (None, 14, 14, 728)  0           ['add_9[0][0]']
#
#  separable_conv2d_27 (Separable  (None, 14, 14, 728)  537264     ['activation_29[0][0]']
#  Conv2D)
#
#  batch_normalization_29 (BatchN  (None, 14, 14, 728)  2912       ['separable_conv2d_27[0][0]']
#  ormalization)
#
#  activation_30 (Activation)     (None, 14, 14, 728)  0           ['batch_normalization_29[0][0]']
#
#  separable_conv2d_28 (Separable  (None, 14, 14, 728)  537264     ['activation_30[0][0]']
#  Conv2D)
#
#  batch_normalization_30 (BatchN  (None, 14, 14, 728)  2912       ['separable_conv2d_28[0][0]']
#  ormalization)
#
#  activation_31 (Activation)     (None, 14, 14, 728)  0           ['batch_normalization_30[0][0]']
#
#  separable_conv2d_29 (Separable  (None, 14, 14, 728)  537264     ['activation_31[0][0]']
#  Conv2D)
#
#  batch_normalization_31 (BatchN  (None, 14, 14, 728)  2912       ['separable_conv2d_29[0][0]']
#  ormalization)
#
#  add_10 (Add)                   (None, 14, 14, 728)  0           ['batch_normalization_31[0][0]',
#                                                                   'add_9[0][0]']
#
#  activation_32 (Activation)     (None, 14, 14, 728)  0           ['add_10[0][0]']
#
#  separable_conv2d_30 (Separable  (None, 14, 14, 728)  537264     ['activation_32[0][0]']
#  Conv2D)
#
#  batch_normalization_32 (BatchN  (None, 14, 14, 728)  2912       ['separable_conv2d_30[0][0]']
#  ormalization)
#
#  activation_33 (Activation)     (None, 14, 14, 728)  0           ['batch_normalization_32[0][0]']
#
#  separable_conv2d_31 (Separable  (None, 14, 14, 1024  753048     ['activation_33[0][0]']
#  Conv2D)                        )
#
#  batch_normalization_33 (BatchN  (None, 14, 14, 1024  4096       ['separable_conv2d_31[0][0]']
#  ormalization)                  )
#
#  max_pooling2d_3 (MaxPooling2D)  (None, 7, 7, 1024)  0           ['batch_normalization_33[0][0]']
#
#  conv2d_5 (Conv2D)              (None, 7, 7, 1024)   746496      ['add_10[0][0]']
#
#  add_11 (Add)                   (None, 7, 7, 1024)   0           ['max_pooling2d_3[0][0]',
#                                                                   'conv2d_5[0][0]']
#
#  separable_conv2d_32 (Separable  (None, 7, 7, 1536)  1583616     ['add_11[0][0]']
#  Conv2D)
#
#  batch_normalization_34 (BatchN  (None, 7, 7, 1536)  6144        ['separable_conv2d_32[0][0]']
#  ormalization)
#
#  activation_34 (Activation)     (None, 7, 7, 1536)   0           ['batch_normalization_34[0][0]']
#
#  separable_conv2d_33 (Separable  (None, 7, 7, 2048)  3161600     ['activation_34[0][0]']
#  Conv2D)
#
#  batch_normalization_35 (BatchN  (None, 7, 7, 2048)  8192        ['separable_conv2d_33[0][0]']
#  ormalization)
#
#  activation_35 (Activation)     (None, 7, 7, 2048)   0           ['batch_normalization_35[0][0]']
#
#  global_average_pooling2d (Glob  (None, 2048)        0           ['activation_35[0][0]']
#  alAveragePooling2D)
#
#  dense (Dense)                  (None, 4)            8196        ['global_average_pooling2d[0][0]'
#                                                                  ]
#
# ==================================================================================================
# Total params: 20,888,396
# Trainable params: 20,838,140
# Non-trainable params: 50,256
# __________________________________________________________________________________________________

# %%
# Fit the model and store the history
history = model.fit(
    train_generator,
    steps_per_epoch=num_train_samples // batch_size,
    epochs=num_epoch,
    validation_data=validation_generator,
    validation_steps=num_validation_samples // batch_size
)
# Out:
# Epoch 1/30
# 400/400 [==============================] - 1145s 3s/step - loss: 0.8976 - accuracy: 0.6400 - val_loss: 1.7747 - val_accuracy: 0.3050
# Epoch 2/30
# 400/400 [==============================] - 154s 385ms/step - loss: 0.6020 - accuracy: 0.7759 - val_loss: 4.0571 - val_accuracy: 0.3065
# Epoch 3/30
# 400/400 [==============================] - 154s 384ms/step - loss: 0.4228 - accuracy: 0.8454 - val_loss: 1.2029 - val_accuracy: 0.7260
# Epoch 4/30
# 400/400 [==============================] - 151s 378ms/step - loss: 0.3696 - accuracy: 0.8640 - val_loss: 1.4461 - val_accuracy: 0.6050
# Epoch 5/30
# 400/400 [==============================] - 155s 388ms/step - loss: 0.2979 - accuracy: 0.8939 - val_loss: 0.2312 - val_accuracy: 0.9250
# Epoch 6/30
# 400/400 [==============================] - 151s 378ms/step - loss: 0.2684 - accuracy: 0.9044 - val_loss: 0.3421 - val_accuracy: 0.8840
# Epoch 7/30
# 400/400 [==============================] - 147s 367ms/step - loss: 0.2298 - accuracy: 0.9215 - val_loss: 0.5698 - val_accuracy: 0.8450
# Epoch 8/30
# 400/400 [==============================] - 146s 366ms/step - loss: 0.2149 - accuracy: 0.9236 - val_loss: 0.1585 - val_accuracy: 0.9510
# Epoch 9/30
# 400/400 [==============================] - 147s 367ms/step - loss: 0.2051 - accuracy: 0.9305 - val_loss: 0.1667 - val_accuracy: 0.9460
# Epoch 10/30
# 400/400 [==============================] - 144s 359ms/step - loss: 0.1822 - accuracy: 0.9376 - val_loss: 0.2095 - val_accuracy: 0.9270
# Epoch 11/30
# 400/400 [==============================] - 143s 358ms/step - loss: 0.1610 - accuracy: 0.9451 - val_loss: 0.4202 - val_accuracy: 0.8795
# Epoch 12/30
# 400/400 [==============================] - 146s 364ms/step - loss: 0.1528 - accuracy: 0.9476 - val_loss: 0.6078 - val_accuracy: 0.8175
# Epoch 13/30
# 400/400 [==============================] - 143s 357ms/step - loss: 0.1504 - accuracy: 0.9488 - val_loss: 0.3233 - val_accuracy: 0.8960
# Epoch 14/30
# 400/400 [==============================] - 150s 374ms/step - loss: 0.1343 - accuracy: 0.9540 - val_loss: 0.2572 - val_accuracy: 0.9230
# Epoch 15/30
# 400/400 [==============================] - 145s 362ms/step - loss: 0.1241 - accuracy: 0.9591 - val_loss: 0.2773 - val_accuracy: 0.8945
# Epoch 16/30
# 400/400 [==============================] - 146s 365ms/step - loss: 0.1302 - accuracy: 0.9534 - val_loss: 0.1562 - val_accuracy: 0.9535
# Epoch 17/30
# 400/400 [==============================] - 142s 355ms/step - loss: 0.1129 - accuracy: 0.9638 - val_loss: 0.1886 - val_accuracy: 0.9430
# Epoch 18/30
# 400/400 [==============================] - 144s 361ms/step - loss: 0.1041 - accuracy: 0.9649 - val_loss: 0.3065 - val_accuracy: 0.9240
# Epoch 19/30
# 400/400 [==============================] - 148s 368ms/step - loss: 0.0934 - accuracy: 0.9699 - val_loss: 0.1138 - val_accuracy: 0.9625
# Epoch 20/30
# 400/400 [==============================] - 155s 388ms/step - loss: 0.0969 - accuracy: 0.9665 - val_loss: 0.0963 - val_accuracy: 0.9725
# Epoch 21/30
# 400/400 [==============================] - 145s 362ms/step - loss: 0.1066 - accuracy: 0.9651 - val_loss: 0.0983 - val_accuracy: 0.9655
# Epoch 22/30
# 400/400 [==============================] - 147s 367ms/step - loss: 0.0888 - accuracy: 0.9697 - val_loss: 0.2064 - val_accuracy: 0.9315
# Epoch 23/30
# 400/400 [==============================] - 145s 362ms/step - loss: 0.0814 - accuracy: 0.9734 - val_loss: 0.1980 - val_accuracy: 0.9400
# Epoch 24/30
# 400/400 [==============================] - 147s 368ms/step - loss: 0.0906 - accuracy: 0.9693 - val_loss: 0.1118 - val_accuracy: 0.9725
# Epoch 25/30
# 400/400 [==============================] - 147s 367ms/step - loss: 0.0778 - accuracy: 0.9755 - val_loss: 0.1136 - val_accuracy: 0.9635
# Epoch 26/30
# 400/400 [==============================] - 143s 356ms/step - loss: 0.0672 - accuracy: 0.9781 - val_loss: 0.1181 - val_accuracy: 0.9665
# Epoch 27/30
# 400/400 [==============================] - 145s 362ms/step - loss: 0.0716 - accuracy: 0.9745 - val_loss: 0.1541 - val_accuracy: 0.9445
# Epoch 28/30
# 400/400 [==============================] - 143s 359ms/step - loss: 0.0736 - accuracy: 0.9764 - val_loss: 0.0730 - val_accuracy: 0.9730
# Epoch 29/30
# 400/400 [==============================] - 144s 360ms/step - loss: 0.0592 - accuracy: 0.9790 - val_loss: 0.0396 - val_accuracy: 0.9875
# Epoch 30/30
# 400/400 [==============================] - 145s 362ms/step - loss: 0.0742 - accuracy: 0.9749 - val_loss: 0.3153 - val_accuracy: 0.9035

# %%
# Plot training accuracy graph
epochs = range(1, num_epoch + 1)
train_acc = model.history.history['accuracy']  # Use 'accuracy' instead of 'acc'
plt.plot(epochs, train_acc, 'b', label='Training Accuracy')
plt.title('Training Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

# Plot validation accuracy graph
val_acc = model.history.history['val_accuracy']  # Use 'val_accuracy' instead of 'val_acc'
plt.plot(epochs, val_acc, 'r', label='Validation Accuracy')
plt.title('Validation Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

# Plot training and validation accuracy graph together
plt.plot(epochs, train_acc, 'b', label='Training Accuracy')
plt.plot(epochs, val_acc, 'r', label='Validation Accuracy')
plt.title('Training and Validation Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

# %%
import matplotlib.pyplot as plt
import matplotlib.font_manager as fm
from matplotlib.font_manager import FontProperties
import numpy as np
import matplotlib.pyplot as plt
from sklearn.metrics import accuracy_score, f1_score, confusion_matrix
import itertools  # Import itertools module

# Generate predictions
y_train_pred = model.predict(train_generator)
y_val_pred = model.predict(validation_generator)

# Get true labels
y_train_true = train_generator.classes
y_val_true = validation_generator.classes

# Calculate accuracy
val_accuracy = accuracy_score(y_val_true, np.argmax(y_val_pred, axis=1))

# Calculate F1 score
train_f1_score = f1_score(y_train_true, np.argmax(y_train_pred, axis=1), average='weighted')
val_f1_score = f1_score(y_val_true, np.argmax(y_val_pred, axis=1), average='weighted')

print("Validation Accuracy: {:.2f}%".format(val_accuracy * 100))
print("Validation F1 Score: {:.2f}".format(val_f1_score))
# Out:
# 400/400 [==============================] - 126s 314ms/step
# 100/100 [==============================] - 8s 79ms/step
# Validation Accuracy: 90.35%
# Validation F1 Score: 0.91

# %%
# Confusion matrix
val_cm = confusion_matrix(y_val_true, np.argmax(y_val_pred, axis=1))

# Plot confusion matrix
def plot_confusion_matrix(cm, classes, normalize=False, title='Confusion matrix', cmap=plt.cm.BuGn):
    """
    This function prints and plots the confusion matrix.
    Normalization can be applied by setting `normalize=True`.
    """
    plt.figure(figsize=(6, 6))
    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation=45)
    plt.yticks(tick_marks, classes)

    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
        print("Normalized confusion matrix")
    else:
        print('Confusion matrix, without normalization')

    print(cm)

    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, cm[i, j],
                 horizontalalignment="center",
                 color="white" if cm[i, j] > thresh else "black")
    plt.tight_layout()
    plt.ylabel('True label')
    plt.xlabel('Predicted label')
    plt.tight_layout()

class_names = train_generator.class_indices.keys()
plot_confusion_matrix(val_cm, classes=class_names, title='Validation Confusion Matrix')
# Out:
# Confusion matrix, without normalization
# [[427   4   0  69]
#  [  6 408  11  75]
#  [  3   0 473  24]
#  [  0   1   0 499]]

# %%
import seaborn as sns
#  "Accuracy"
plt.figure(figsize=[8, 4])
sns.set_theme()
plt.plot(history.history['accuracy'], 'o-', color="Green")
plt.plot(history.history['val_accuracy'] , 'o-', color="Red")
plt.title('Model Accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='lower right')
#plt.show()
plt.gca().set_position([0.1, 0.12, 0.8, 0.8])
# "Loss"
plt.figure(figsize=[8, 4])
sns.set_theme()
plt.plot(history.history['loss'], 'o-', color="Green")
plt.plot(history.history['val_loss'], 'o-', color="Red")
plt.title('Model Loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper right')
#plt.show()
plt.gca().set_position([0.1, 0.12, 0.8, 0.8])
