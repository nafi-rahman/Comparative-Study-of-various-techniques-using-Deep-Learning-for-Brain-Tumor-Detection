# %% [markdown]
# <a href="https://colab.research.google.com/github/nafi-rahman/Comparative-Study-of-various-techniques-using-Deep-Learning-for-Brain-Tumor-Detection/blob/main/BrainTumor(denseNet).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import cv2
from imgaug import augmenters as iaa
import os
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from keras.utils import to_categorical
from keras.applications import resnet
from tensorflow.keras.applications import VGG16, ResNet50, ResNet101, InceptionResNetV2
from tensorflow.keras.layers import AveragePooling2D
from tensorflow.keras.layers import Dropout
from tensorflow.keras.layers import Flatten
from tensorflow.keras.layers import Dense
from tensorflow.keras.layers import Input
from tensorflow.keras.models import Model
from tensorflow.keras.optimizers import Adam, SGD
from tensorflow.keras.utils import to_categorical
from sklearn.preprocessing import LabelBinarizer
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix
from imutils import paths
import matplotlib.pyplot as plt
import numpy as np
import argparse
import cv2
import os
from keras import Sequential
from keras.layers import Dense, GlobalAveragePooling2D, Dropout, BatchNormalization
from keras.callbacks import EarlyStopping, ModelCheckpoint

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
from PIL import Image
from tensorflow.keras.preprocessing.image import ImageDataGenerator
import os

img_rows, img_cols = 224, 224

isolated_train_path = "/content/drive/MyDrive/Database/BrainTumor(10K_new)/Training"
isolated_test_path = "/content/drive/MyDrive/Database/BrainTumor(10K_new)/Testing"

for root, dirnames, filenames in os.walk(isolated_train_path):
    for filename in filenames:
        file_path = os.path.join(root, filename)
        img = Image.open(file_path)
        grey = img.resize((img_rows, img_cols))
        grey.save(file_path)

train_data_dir = isolated_train_path
validation_data_dir = isolated_test_path

img_width, img_height, channel = img_rows, img_cols, 3
batch_size = 20

# Data augmentation settings
train_datagen = ImageDataGenerator(
    rescale=1.0/255.0,
    rotation_range=20,  # Rotate images randomly up to 20 degrees
    width_shift_range=0.2,  # Shift the width of the image randomly
    height_shift_range=0.2,  # Shift the height of the image randomly
    shear_range=0.2,  # Apply shear transformation randomly
    zoom_range=0.2,  # Zoom in/out randomly
    horizontal_flip=True,  # Flip images horizontally
    fill_mode='nearest'  # Fill newly created pixels after rotation or shift
)

validation_datagen = ImageDataGenerator(rescale=1./244)  # Only rescale for validation data

# Automatically retrieve images and their classes for training and validation
train_generator = train_datagen.flow_from_directory(
    train_data_dir,
    target_size=(img_width, img_height),
    batch_size=batch_size,
    shuffle=True,
    class_mode='categorical'
)

validation_generator = validation_datagen.flow_from_directory(
    validation_data_dir,
    target_size=(img_width, img_height),
    batch_size=batch_size,
    shuffle=False,
    class_mode='categorical'
)

IMG_SHAPE = img_cols, img_rows, 3
classes = 4

num_epoch = 30
num_train_samples = train_generator.samples
num_validation_samples = validation_generator.samples

print('num_train_samples:', num_train_samples)
print('num_validation_samples:', num_validation_samples)
# Out:
# Found 8000 images belonging to 4 classes.
# Found 2000 images belonging to 4 classes.
# num_train_samples: 8000
# num_validation_samples: 2000

# %%
class_names = list(train_generator.class_indices.keys())
print(class_names)

class_names = list(validation_generator.class_indices.keys())
print(class_names)

print(train_generator.class_indices)
print(validation_generator.class_indices)
# Out:
# ['glioma', 'meningioma', 'notumor', 'pituitary']
# ['glioma', 'meningioma', 'notumor', 'pituitary']
# {'glioma': 0, 'meningioma': 1, 'notumor': 2, 'pituitary': 3}
# {'glioma': 0, 'meningioma': 1, 'notumor': 2, 'pituitary': 3}

# %%
import matplotlib.pyplot as plt
import numpy as np

# Get true labels
y_train_true = train_generator.classes

# Count samples per class
unique_classes, class_counts = np.unique(y_train_true, return_counts=True)
for class_label, count in zip(unique_classes, class_counts):
    print("Class {}: {} samples".format(class_label, count))


# Plot class distribution
plt.bar(unique_classes, class_counts)
plt.xlabel('Class')
plt.ylabel('Number of Samples')
plt.title('Class Distribution')
plt.show()
# Out:
# Class 0: 2000 samples
# Class 1: 2000 samples
# Class 2: 2000 samples
# Class 3: 2000 samples

# %%
#denseNet

from tensorflow.keras import layers, models

def dense_net(input_shape, num_classes):
    growth_rate = 32

    # Dense block
    def dense_block(x, blocks):
        for _ in range(blocks):
            x1 = layers.BatchNormalization()(x)
            x1 = layers.Activation('relu')(x1)
            x1 = layers.Conv2D(growth_rate, (3, 3), padding='same')(x1)
            x = layers.concatenate([x, x1], axis=-1)
        return x

    # Transition block
    def transition_block(x):
        x = layers.BatchNormalization()(x)
        x = layers.Activation('relu')(x)
        x = layers.Conv2D(growth_rate, (1, 1), padding='same')(x)
        x = layers.AveragePooling2D((2, 2), strides=(2, 2))(x)
        return x

    # Initial layers
    inputs = layers.Input(shape=input_shape)
    x = layers.Conv2D(64, (7, 7), strides=(2, 2), padding='same')(inputs)
    x = layers.BatchNormalization()(x)
    x = layers.Activation('relu')(x)
    x = layers.MaxPooling2D((3, 3), strides=(2, 2), padding='same')(x)

    # Dense blocks
    x = dense_block(x, blocks=6)
    x = transition_block(x)
    x = dense_block(x, blocks=12)
    x = transition_block(x)
    x = dense_block(x, blocks=24)
    x = transition_block(x)
    x = dense_block(x, blocks=16)

    # Output layer
    x = layers.BatchNormalization()(x)
    x = layers.Activation('relu')(x)
    x = layers.GlobalAveragePooling2D()(x)
    outputs = layers.Dense(num_classes, activation='softmax')(x)

    # Create model
    model = models.Model(inputs, outputs)
    return model

# Define model
input_shape = (224, 224, 3)
num_classes = 4
model = dense_net(input_shape, num_classes)

# Compile model
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# Print model summary
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 224, 224, 3  0           []
#                                 )]
#
#  conv2d (Conv2D)                (None, 112, 112, 64  9472        ['input_1[0][0]']
#                                 )
#
#  batch_normalization (BatchNorm  (None, 112, 112, 64  256        ['conv2d[0][0]']
#  alization)                     )
#
#  activation (Activation)        (None, 112, 112, 64  0           ['batch_normalization[0][0]']
#                                 )
#
#  max_pooling2d (MaxPooling2D)   (None, 56, 56, 64)   0           ['activation[0][0]']
#
#  batch_normalization_1 (BatchNo  (None, 56, 56, 64)  256         ['max_pooling2d[0][0]']
#  rmalization)
#
#  activation_1 (Activation)      (None, 56, 56, 64)   0           ['batch_normalization_1[0][0]']
#
#  conv2d_1 (Conv2D)              (None, 56, 56, 32)   18464       ['activation_1[0][0]']
#
#  concatenate (Concatenate)      (None, 56, 56, 96)   0           ['max_pooling2d[0][0]',
#                                                                   'conv2d_1[0][0]']
#
#  batch_normalization_2 (BatchNo  (None, 56, 56, 96)  384         ['concatenate[0][0]']
#  rmalization)
#
#  activation_2 (Activation)      (None, 56, 56, 96)   0           ['batch_normalization_2[0][0]']
#
#  conv2d_2 (Conv2D)              (None, 56, 56, 32)   27680       ['activation_2[0][0]']
#
#  concatenate_1 (Concatenate)    (None, 56, 56, 128)  0           ['concatenate[0][0]',
#                                                                   'conv2d_2[0][0]']
#
#  batch_normalization_3 (BatchNo  (None, 56, 56, 128)  512        ['concatenate_1[0][0]']
#  rmalization)
#
#  activation_3 (Activation)      (None, 56, 56, 128)  0           ['batch_normalization_3[0][0]']
#
#  conv2d_3 (Conv2D)              (None, 56, 56, 32)   36896       ['activation_3[0][0]']
#
#  concatenate_2 (Concatenate)    (None, 56, 56, 160)  0           ['concatenate_1[0][0]',
#                                                                   'conv2d_3[0][0]']
#
#  batch_normalization_4 (BatchNo  (None, 56, 56, 160)  640        ['concatenate_2[0][0]']
#  rmalization)
#
#  activation_4 (Activation)      (None, 56, 56, 160)  0           ['batch_normalization_4[0][0]']
#
#  conv2d_4 (Conv2D)              (None, 56, 56, 32)   46112       ['activation_4[0][0]']
#
#  concatenate_3 (Concatenate)    (None, 56, 56, 192)  0           ['concatenate_2[0][0]',
#                                                                   'conv2d_4[0][0]']
#
#  batch_normalization_5 (BatchNo  (None, 56, 56, 192)  768        ['concatenate_3[0][0]']
#  rmalization)
#
#  activation_5 (Activation)      (None, 56, 56, 192)  0           ['batch_normalization_5[0][0]']
#
#  conv2d_5 (Conv2D)              (None, 56, 56, 32)   55328       ['activation_5[0][0]']
#
#  concatenate_4 (Concatenate)    (None, 56, 56, 224)  0           ['concatenate_3[0][0]',
#                                                                   'conv2d_5[0][0]']
#
#  batch_normalization_6 (BatchNo  (None, 56, 56, 224)  896        ['concatenate_4[0][0]']
#  rmalization)
#
#  activation_6 (Activation)      (None, 56, 56, 224)  0           ['batch_normalization_6[0][0]']
#
#  conv2d_6 (Conv2D)              (None, 56, 56, 32)   64544       ['activation_6[0][0]']
#
#  concatenate_5 (Concatenate)    (None, 56, 56, 256)  0           ['concatenate_4[0][0]',
#                                                                   'conv2d_6[0][0]']
#
#  batch_normalization_7 (BatchNo  (None, 56, 56, 256)  1024       ['concatenate_5[0][0]']
#  rmalization)
#
#  activation_7 (Activation)      (None, 56, 56, 256)  0           ['batch_normalization_7[0][0]']
#
#  conv2d_7 (Conv2D)              (None, 56, 56, 32)   8224        ['activation_7[0][0]']
#
#  average_pooling2d (AveragePool  (None, 28, 28, 32)  0           ['conv2d_7[0][0]']
#  ing2D)
#
#  batch_normalization_8 (BatchNo  (None, 28, 28, 32)  128         ['average_pooling2d[0][0]']
#  rmalization)
#
#  activation_8 (Activation)      (None, 28, 28, 32)   0           ['batch_normalization_8[0][0]']
#
#  conv2d_8 (Conv2D)              (None, 28, 28, 32)   9248        ['activation_8[0][0]']
#
#  concatenate_6 (Concatenate)    (None, 28, 28, 64)   0           ['average_pooling2d[0][0]',
#                                                                   'conv2d_8[0][0]']
#
#  batch_normalization_9 (BatchNo  (None, 28, 28, 64)  256         ['concatenate_6[0][0]']
#  rmalization)
#
#  activation_9 (Activation)      (None, 28, 28, 64)   0           ['batch_normalization_9[0][0]']
#
#  conv2d_9 (Conv2D)              (None, 28, 28, 32)   18464       ['activation_9[0][0]']
#
#  concatenate_7 (Concatenate)    (None, 28, 28, 96)   0           ['concatenate_6[0][0]',
#                                                                   'conv2d_9[0][0]']
#
#  batch_normalization_10 (BatchN  (None, 28, 28, 96)  384         ['concatenate_7[0][0]']
#  ormalization)
#
#  activation_10 (Activation)     (None, 28, 28, 96)   0           ['batch_normalization_10[0][0]']
#
#  conv2d_10 (Conv2D)             (None, 28, 28, 32)   27680       ['activation_10[0][0]']
#
#  concatenate_8 (Concatenate)    (None, 28, 28, 128)  0           ['concatenate_7[0][0]',
#                                                                   'conv2d_10[0][0]']
#
#  batch_normalization_11 (BatchN  (None, 28, 28, 128)  512        ['concatenate_8[0][0]']
#  ormalization)
#
#  activation_11 (Activation)     (None, 28, 28, 128)  0           ['batch_normalization_11[0][0]']
#
#  conv2d_11 (Conv2D)             (None, 28, 28, 32)   36896       ['activation_11[0][0]']
#
#  concatenate_9 (Concatenate)    (None, 28, 28, 160)  0           ['concatenate_8[0][0]',
#                                                                   'conv2d_11[0][0]']
#
#  batch_normalization_12 (BatchN  (None, 28, 28, 160)  640        ['concatenate_9[0][0]']
#  ormalization)
#
#  activation_12 (Activation)     (None, 28, 28, 160)  0           ['batch_normalization_12[0][0]']
#
#  conv2d_12 (Conv2D)             (None, 28, 28, 32)   46112       ['activation_12[0][0]']
#
#  concatenate_10 (Concatenate)   (None, 28, 28, 192)  0           ['concatenate_9[0][0]',
#                                                                   'conv2d_12[0][0]']
#
#  batch_normalization_13 (BatchN  (None, 28, 28, 192)  768        ['concatenate_10[0][0]']
#  ormalization)
#
#  activation_13 (Activation)     (None, 28, 28, 192)  0           ['batch_normalization_13[0][0]']
#
#  conv2d_13 (Conv2D)             (None, 28, 28, 32)   55328       ['activation_13[0][0]']
#
#  concatenate_11 (Concatenate)   (None, 28, 28, 224)  0           ['concatenate_10[0][0]',
#                                                                   'conv2d_13[0][0]']
#
#  batch_normalization_14 (BatchN  (None, 28, 28, 224)  896        ['concatenate_11[0][0]']
#  ormalization)
#
#  activation_14 (Activation)     (None, 28, 28, 224)  0           ['batch_normalization_14[0][0]']
#
#  conv2d_14 (Conv2D)             (None, 28, 28, 32)   64544       ['activation_14[0][0]']
#
#  concatenate_12 (Concatenate)   (None, 28, 28, 256)  0           ['concatenate_11[0][0]',
#                                                                   'conv2d_14[0][0]']
#
#  batch_normalization_15 (BatchN  (None, 28, 28, 256)  1024       ['concatenate_12[0][0]']
#  ormalization)
#
#  activation_15 (Activation)     (None, 28, 28, 256)  0           ['batch_normalization_15[0][0]']
#
#  conv2d_15 (Conv2D)             (None, 28, 28, 32)   73760       ['activation_15[0][0]']
#
#  concatenate_13 (Concatenate)   (None, 28, 28, 288)  0           ['concatenate_12[0][0]',
#                                                                   'conv2d_15[0][0]']
#
#  batch_normalization_16 (BatchN  (None, 28, 28, 288)  1152       ['concatenate_13[0][0]']
#  ormalization)
#
#  activation_16 (Activation)     (None, 28, 28, 288)  0           ['batch_normalization_16[0][0]']
#
#  conv2d_16 (Conv2D)             (None, 28, 28, 32)   82976       ['activation_16[0][0]']
#
#  concatenate_14 (Concatenate)   (None, 28, 28, 320)  0           ['concatenate_13[0][0]',
#                                                                   'conv2d_16[0][0]']
#
#  batch_normalization_17 (BatchN  (None, 28, 28, 320)  1280       ['concatenate_14[0][0]']
#  ormalization)
#
#  activation_17 (Activation)     (None, 28, 28, 320)  0           ['batch_normalization_17[0][0]']
#
#  conv2d_17 (Conv2D)             (None, 28, 28, 32)   92192       ['activation_17[0][0]']
#
#  concatenate_15 (Concatenate)   (None, 28, 28, 352)  0           ['concatenate_14[0][0]',
#                                                                   'conv2d_17[0][0]']
#
#  batch_normalization_18 (BatchN  (None, 28, 28, 352)  1408       ['concatenate_15[0][0]']
#  ormalization)
#
#  activation_18 (Activation)     (None, 28, 28, 352)  0           ['batch_normalization_18[0][0]']
#
#  conv2d_18 (Conv2D)             (None, 28, 28, 32)   101408      ['activation_18[0][0]']
#
#  concatenate_16 (Concatenate)   (None, 28, 28, 384)  0           ['concatenate_15[0][0]',
#                                                                   'conv2d_18[0][0]']
#
#  batch_normalization_19 (BatchN  (None, 28, 28, 384)  1536       ['concatenate_16[0][0]']
#  ormalization)
#
#  activation_19 (Activation)     (None, 28, 28, 384)  0           ['batch_normalization_19[0][0]']
#
#  conv2d_19 (Conv2D)             (None, 28, 28, 32)   110624      ['activation_19[0][0]']
#
#  concatenate_17 (Concatenate)   (None, 28, 28, 416)  0           ['concatenate_16[0][0]',
#                                                                   'conv2d_19[0][0]']
#
#  batch_normalization_20 (BatchN  (None, 28, 28, 416)  1664       ['concatenate_17[0][0]']
#  ormalization)
#
#  activation_20 (Activation)     (None, 28, 28, 416)  0           ['batch_normalization_20[0][0]']
#
#  conv2d_20 (Conv2D)             (None, 28, 28, 32)   13344       ['activation_20[0][0]']
#
#  average_pooling2d_1 (AveragePo  (None, 14, 14, 32)  0           ['conv2d_20[0][0]']
#  oling2D)
#
#  batch_normalization_21 (BatchN  (None, 14, 14, 32)  128         ['average_pooling2d_1[0][0]']
#  ormalization)
#
#  activation_21 (Activation)     (None, 14, 14, 32)   0           ['batch_normalization_21[0][0]']
#
#  conv2d_21 (Conv2D)             (None, 14, 14, 32)   9248        ['activation_21[0][0]']
#
#  concatenate_18 (Concatenate)   (None, 14, 14, 64)   0           ['average_pooling2d_1[0][0]',
#                                                                   'conv2d_21[0][0]']
#
#  batch_normalization_22 (BatchN  (None, 14, 14, 64)  256         ['concatenate_18[0][0]']
#  ormalization)
#
#  activation_22 (Activation)     (None, 14, 14, 64)   0           ['batch_normalization_22[0][0]']
#
#  conv2d_22 (Conv2D)             (None, 14, 14, 32)   18464       ['activation_22[0][0]']
#
#  concatenate_19 (Concatenate)   (None, 14, 14, 96)   0           ['concatenate_18[0][0]',
#                                                                   'conv2d_22[0][0]']
#
#  batch_normalization_23 (BatchN  (None, 14, 14, 96)  384         ['concatenate_19[0][0]']
#  ormalization)
#
#  activation_23 (Activation)     (None, 14, 14, 96)   0           ['batch_normalization_23[0][0]']
#
#  conv2d_23 (Conv2D)             (None, 14, 14, 32)   27680       ['activation_23[0][0]']
#
#  concatenate_20 (Concatenate)   (None, 14, 14, 128)  0           ['concatenate_19[0][0]',
#                                                                   'conv2d_23[0][0]']
#
#  batch_normalization_24 (BatchN  (None, 14, 14, 128)  512        ['concatenate_20[0][0]']
#  ormalization)
#
#  activation_24 (Activation)     (None, 14, 14, 128)  0           ['batch_normalization_24[0][0]']
#
#  conv2d_24 (Conv2D)             (None, 14, 14, 32)   36896       ['activation_24[0][0]']
#
#  concatenate_21 (Concatenate)   (None, 14, 14, 160)  0           ['concatenate_20[0][0]',
#                                                                   'conv2d_24[0][0]']
#
#  batch_normalization_25 (BatchN  (None, 14, 14, 160)  640        ['concatenate_21[0][0]']
#  ormalization)
#
#  activation_25 (Activation)     (None, 14, 14, 160)  0           ['batch_normalization_25[0][0]']
#
#  conv2d_25 (Conv2D)             (None, 14, 14, 32)   46112       ['activation_25[0][0]']
#
#  concatenate_22 (Concatenate)   (None, 14, 14, 192)  0           ['concatenate_21[0][0]',
#                                                                   'conv2d_25[0][0]']
#
#  batch_normalization_26 (BatchN  (None, 14, 14, 192)  768        ['concatenate_22[0][0]']
#  ormalization)
#
#  activation_26 (Activation)     (None, 14, 14, 192)  0           ['batch_normalization_26[0][0]']
#
#  conv2d_26 (Conv2D)             (None, 14, 14, 32)   55328       ['activation_26[0][0]']
#
#  concatenate_23 (Concatenate)   (None, 14, 14, 224)  0           ['concatenate_22[0][0]',
#                                                                   'conv2d_26[0][0]']
#
#  batch_normalization_27 (BatchN  (None, 14, 14, 224)  896        ['concatenate_23[0][0]']
#  ormalization)
#
#  activation_27 (Activation)     (None, 14, 14, 224)  0           ['batch_normalization_27[0][0]']
#
#  conv2d_27 (Conv2D)             (None, 14, 14, 32)   64544       ['activation_27[0][0]']
#
#  concatenate_24 (Concatenate)   (None, 14, 14, 256)  0           ['concatenate_23[0][0]',
#                                                                   'conv2d_27[0][0]']
#
#  batch_normalization_28 (BatchN  (None, 14, 14, 256)  1024       ['concatenate_24[0][0]']
#  ormalization)
#
#  activation_28 (Activation)     (None, 14, 14, 256)  0           ['batch_normalization_28[0][0]']
#
#  conv2d_28 (Conv2D)             (None, 14, 14, 32)   73760       ['activation_28[0][0]']
#
#  concatenate_25 (Concatenate)   (None, 14, 14, 288)  0           ['concatenate_24[0][0]',
#                                                                   'conv2d_28[0][0]']
#
#  batch_normalization_29 (BatchN  (None, 14, 14, 288)  1152       ['concatenate_25[0][0]']
#  ormalization)
#
#  activation_29 (Activation)     (None, 14, 14, 288)  0           ['batch_normalization_29[0][0]']
#
#  conv2d_29 (Conv2D)             (None, 14, 14, 32)   82976       ['activation_29[0][0]']
#
#  concatenate_26 (Concatenate)   (None, 14, 14, 320)  0           ['concatenate_25[0][0]',
#                                                                   'conv2d_29[0][0]']
#
#  batch_normalization_30 (BatchN  (None, 14, 14, 320)  1280       ['concatenate_26[0][0]']
#  ormalization)
#
#  activation_30 (Activation)     (None, 14, 14, 320)  0           ['batch_normalization_30[0][0]']
#
#  conv2d_30 (Conv2D)             (None, 14, 14, 32)   92192       ['activation_30[0][0]']
#
#  concatenate_27 (Concatenate)   (None, 14, 14, 352)  0           ['concatenate_26[0][0]',
#                                                                   'conv2d_30[0][0]']
#
#  batch_normalization_31 (BatchN  (None, 14, 14, 352)  1408       ['concatenate_27[0][0]']
#  ormalization)
#
#  activation_31 (Activation)     (None, 14, 14, 352)  0           ['batch_normalization_31[0][0]']
#
#  conv2d_31 (Conv2D)             (None, 14, 14, 32)   101408      ['activation_31[0][0]']
#
#  concatenate_28 (Concatenate)   (None, 14, 14, 384)  0           ['concatenate_27[0][0]',
#                                                                   'conv2d_31[0][0]']
#
#  batch_normalization_32 (BatchN  (None, 14, 14, 384)  1536       ['concatenate_28[0][0]']
#  ormalization)
#
#  activation_32 (Activation)     (None, 14, 14, 384)  0           ['batch_normalization_32[0][0]']
#
#  conv2d_32 (Conv2D)             (None, 14, 14, 32)   110624      ['activation_32[0][0]']
#
#  concatenate_29 (Concatenate)   (None, 14, 14, 416)  0           ['concatenate_28[0][0]',
#                                                                   'conv2d_32[0][0]']
#
#  batch_normalization_33 (BatchN  (None, 14, 14, 416)  1664       ['concatenate_29[0][0]']
#  ormalization)
#
#  activation_33 (Activation)     (None, 14, 14, 416)  0           ['batch_normalization_33[0][0]']
#
#  conv2d_33 (Conv2D)             (None, 14, 14, 32)   119840      ['activation_33[0][0]']
#
#  concatenate_30 (Concatenate)   (None, 14, 14, 448)  0           ['concatenate_29[0][0]',
#                                                                   'conv2d_33[0][0]']
#
#  batch_normalization_34 (BatchN  (None, 14, 14, 448)  1792       ['concatenate_30[0][0]']
#  ormalization)
#
#  activation_34 (Activation)     (None, 14, 14, 448)  0           ['batch_normalization_34[0][0]']
#
#  conv2d_34 (Conv2D)             (None, 14, 14, 32)   129056      ['activation_34[0][0]']
#
#  concatenate_31 (Concatenate)   (None, 14, 14, 480)  0           ['concatenate_30[0][0]',
#                                                                   'conv2d_34[0][0]']
#
#  batch_normalization_35 (BatchN  (None, 14, 14, 480)  1920       ['concatenate_31[0][0]']
#  ormalization)
#
#  activation_35 (Activation)     (None, 14, 14, 480)  0           ['batch_normalization_35[0][0]']
#
#  conv2d_35 (Conv2D)             (None, 14, 14, 32)   138272      ['activation_35[0][0]']
#
#  concatenate_32 (Concatenate)   (None, 14, 14, 512)  0           ['concatenate_31[0][0]',
#                                                                   'conv2d_35[0][0]']
#
#  batch_normalization_36 (BatchN  (None, 14, 14, 512)  2048       ['concatenate_32[0][0]']
#  ormalization)
#
#  activation_36 (Activation)     (None, 14, 14, 512)  0           ['batch_normalization_36[0][0]']
#
#  conv2d_36 (Conv2D)             (None, 14, 14, 32)   147488      ['activation_36[0][0]']
#
#  concatenate_33 (Concatenate)   (None, 14, 14, 544)  0           ['concatenate_32[0][0]',
#                                                                   'conv2d_36[0][0]']
#
#  batch_normalization_37 (BatchN  (None, 14, 14, 544)  2176       ['concatenate_33[0][0]']
#  ormalization)
#
#  activation_37 (Activation)     (None, 14, 14, 544)  0           ['batch_normalization_37[0][0]']
#
#  conv2d_37 (Conv2D)             (None, 14, 14, 32)   156704      ['activation_37[0][0]']
#
#  concatenate_34 (Concatenate)   (None, 14, 14, 576)  0           ['concatenate_33[0][0]',
#                                                                   'conv2d_37[0][0]']
#
#  batch_normalization_38 (BatchN  (None, 14, 14, 576)  2304       ['concatenate_34[0][0]']
#  ormalization)
#
#  activation_38 (Activation)     (None, 14, 14, 576)  0           ['batch_normalization_38[0][0]']
#
#  conv2d_38 (Conv2D)             (None, 14, 14, 32)   165920      ['activation_38[0][0]']
#
#  concatenate_35 (Concatenate)   (None, 14, 14, 608)  0           ['concatenate_34[0][0]',
#                                                                   'conv2d_38[0][0]']
#
#  batch_normalization_39 (BatchN  (None, 14, 14, 608)  2432       ['concatenate_35[0][0]']
#  ormalization)
#
#  activation_39 (Activation)     (None, 14, 14, 608)  0           ['batch_normalization_39[0][0]']
#
#  conv2d_39 (Conv2D)             (None, 14, 14, 32)   175136      ['activation_39[0][0]']
#
#  concatenate_36 (Concatenate)   (None, 14, 14, 640)  0           ['concatenate_35[0][0]',
#                                                                   'conv2d_39[0][0]']
#
#  batch_normalization_40 (BatchN  (None, 14, 14, 640)  2560       ['concatenate_36[0][0]']
#  ormalization)
#
#  activation_40 (Activation)     (None, 14, 14, 640)  0           ['batch_normalization_40[0][0]']
#
#  conv2d_40 (Conv2D)             (None, 14, 14, 32)   184352      ['activation_40[0][0]']
#
#  concatenate_37 (Concatenate)   (None, 14, 14, 672)  0           ['concatenate_36[0][0]',
#                                                                   'conv2d_40[0][0]']
#
#  batch_normalization_41 (BatchN  (None, 14, 14, 672)  2688       ['concatenate_37[0][0]']
#  ormalization)
#
#  activation_41 (Activation)     (None, 14, 14, 672)  0           ['batch_normalization_41[0][0]']
#
#  conv2d_41 (Conv2D)             (None, 14, 14, 32)   193568      ['activation_41[0][0]']
#
#  concatenate_38 (Concatenate)   (None, 14, 14, 704)  0           ['concatenate_37[0][0]',
#                                                                   'conv2d_41[0][0]']
#
#  batch_normalization_42 (BatchN  (None, 14, 14, 704)  2816       ['concatenate_38[0][0]']
#  ormalization)
#
#  activation_42 (Activation)     (None, 14, 14, 704)  0           ['batch_normalization_42[0][0]']
#
#  conv2d_42 (Conv2D)             (None, 14, 14, 32)   202784      ['activation_42[0][0]']
#
#  concatenate_39 (Concatenate)   (None, 14, 14, 736)  0           ['concatenate_38[0][0]',
#                                                                   'conv2d_42[0][0]']
#
#  batch_normalization_43 (BatchN  (None, 14, 14, 736)  2944       ['concatenate_39[0][0]']
#  ormalization)
#
#  activation_43 (Activation)     (None, 14, 14, 736)  0           ['batch_normalization_43[0][0]']
#
#  conv2d_43 (Conv2D)             (None, 14, 14, 32)   212000      ['activation_43[0][0]']
#
#  concatenate_40 (Concatenate)   (None, 14, 14, 768)  0           ['concatenate_39[0][0]',
#                                                                   'conv2d_43[0][0]']
#
#  batch_normalization_44 (BatchN  (None, 14, 14, 768)  3072       ['concatenate_40[0][0]']
#  ormalization)
#
#  activation_44 (Activation)     (None, 14, 14, 768)  0           ['batch_normalization_44[0][0]']
#
#  conv2d_44 (Conv2D)             (None, 14, 14, 32)   221216      ['activation_44[0][0]']
#
#  concatenate_41 (Concatenate)   (None, 14, 14, 800)  0           ['concatenate_40[0][0]',
#                                                                   'conv2d_44[0][0]']
#
#  batch_normalization_45 (BatchN  (None, 14, 14, 800)  3200       ['concatenate_41[0][0]']
#  ormalization)
#
#  activation_45 (Activation)     (None, 14, 14, 800)  0           ['batch_normalization_45[0][0]']
#
#  conv2d_45 (Conv2D)             (None, 14, 14, 32)   25632       ['activation_45[0][0]']
#
#  average_pooling2d_2 (AveragePo  (None, 7, 7, 32)    0           ['conv2d_45[0][0]']
#  oling2D)
#
#  batch_normalization_46 (BatchN  (None, 7, 7, 32)    128         ['average_pooling2d_2[0][0]']
#  ormalization)
#
#  activation_46 (Activation)     (None, 7, 7, 32)     0           ['batch_normalization_46[0][0]']
#
#  conv2d_46 (Conv2D)             (None, 7, 7, 32)     9248        ['activation_46[0][0]']
#
#  concatenate_42 (Concatenate)   (None, 7, 7, 64)     0           ['average_pooling2d_2[0][0]',
#                                                                   'conv2d_46[0][0]']
#
#  batch_normalization_47 (BatchN  (None, 7, 7, 64)    256         ['concatenate_42[0][0]']
#  ormalization)
#
#  activation_47 (Activation)     (None, 7, 7, 64)     0           ['batch_normalization_47[0][0]']
#
#  conv2d_47 (Conv2D)             (None, 7, 7, 32)     18464       ['activation_47[0][0]']
#
#  concatenate_43 (Concatenate)   (None, 7, 7, 96)     0           ['concatenate_42[0][0]',
#                                                                   'conv2d_47[0][0]']
#
#  batch_normalization_48 (BatchN  (None, 7, 7, 96)    384         ['concatenate_43[0][0]']
#  ormalization)
#
#  activation_48 (Activation)     (None, 7, 7, 96)     0           ['batch_normalization_48[0][0]']
#
#  conv2d_48 (Conv2D)             (None, 7, 7, 32)     27680       ['activation_48[0][0]']
#
#  concatenate_44 (Concatenate)   (None, 7, 7, 128)    0           ['concatenate_43[0][0]',
#                                                                   'conv2d_48[0][0]']
#
#  batch_normalization_49 (BatchN  (None, 7, 7, 128)   512         ['concatenate_44[0][0]']
#  ormalization)
#
#  activation_49 (Activation)     (None, 7, 7, 128)    0           ['batch_normalization_49[0][0]']
#
#  conv2d_49 (Conv2D)             (None, 7, 7, 32)     36896       ['activation_49[0][0]']
#
#  concatenate_45 (Concatenate)   (None, 7, 7, 160)    0           ['concatenate_44[0][0]',
#                                                                   'conv2d_49[0][0]']
#
#  batch_normalization_50 (BatchN  (None, 7, 7, 160)   640         ['concatenate_45[0][0]']
#  ormalization)
#
#  activation_50 (Activation)     (None, 7, 7, 160)    0           ['batch_normalization_50[0][0]']
#
#  conv2d_50 (Conv2D)             (None, 7, 7, 32)     46112       ['activation_50[0][0]']
#
#  concatenate_46 (Concatenate)   (None, 7, 7, 192)    0           ['concatenate_45[0][0]',
#                                                                   'conv2d_50[0][0]']
#
#  batch_normalization_51 (BatchN  (None, 7, 7, 192)   768         ['concatenate_46[0][0]']
#  ormalization)
#
#  activation_51 (Activation)     (None, 7, 7, 192)    0           ['batch_normalization_51[0][0]']
#
#  conv2d_51 (Conv2D)             (None, 7, 7, 32)     55328       ['activation_51[0][0]']
#
#  concatenate_47 (Concatenate)   (None, 7, 7, 224)    0           ['concatenate_46[0][0]',
#                                                                   'conv2d_51[0][0]']
#
#  batch_normalization_52 (BatchN  (None, 7, 7, 224)   896         ['concatenate_47[0][0]']
#  ormalization)
#
#  activation_52 (Activation)     (None, 7, 7, 224)    0           ['batch_normalization_52[0][0]']
#
#  conv2d_52 (Conv2D)             (None, 7, 7, 32)     64544       ['activation_52[0][0]']
#
#  concatenate_48 (Concatenate)   (None, 7, 7, 256)    0           ['concatenate_47[0][0]',
#                                                                   'conv2d_52[0][0]']
#
#  batch_normalization_53 (BatchN  (None, 7, 7, 256)   1024        ['concatenate_48[0][0]']
#  ormalization)
#
#  activation_53 (Activation)     (None, 7, 7, 256)    0           ['batch_normalization_53[0][0]']
#
#  conv2d_53 (Conv2D)             (None, 7, 7, 32)     73760       ['activation_53[0][0]']
#
#  concatenate_49 (Concatenate)   (None, 7, 7, 288)    0           ['concatenate_48[0][0]',
#                                                                   'conv2d_53[0][0]']
#
#  batch_normalization_54 (BatchN  (None, 7, 7, 288)   1152        ['concatenate_49[0][0]']
#  ormalization)
#
#  activation_54 (Activation)     (None, 7, 7, 288)    0           ['batch_normalization_54[0][0]']
#
#  conv2d_54 (Conv2D)             (None, 7, 7, 32)     82976       ['activation_54[0][0]']
#
#  concatenate_50 (Concatenate)   (None, 7, 7, 320)    0           ['concatenate_49[0][0]',
#                                                                   'conv2d_54[0][0]']
#
#  batch_normalization_55 (BatchN  (None, 7, 7, 320)   1280        ['concatenate_50[0][0]']
#  ormalization)
#
#  activation_55 (Activation)     (None, 7, 7, 320)    0           ['batch_normalization_55[0][0]']
#
#  conv2d_55 (Conv2D)             (None, 7, 7, 32)     92192       ['activation_55[0][0]']
#
#  concatenate_51 (Concatenate)   (None, 7, 7, 352)    0           ['concatenate_50[0][0]',
#                                                                   'conv2d_55[0][0]']
#
#  batch_normalization_56 (BatchN  (None, 7, 7, 352)   1408        ['concatenate_51[0][0]']
#  ormalization)
#
#  activation_56 (Activation)     (None, 7, 7, 352)    0           ['batch_normalization_56[0][0]']
#
#  conv2d_56 (Conv2D)             (None, 7, 7, 32)     101408      ['activation_56[0][0]']
#
#  concatenate_52 (Concatenate)   (None, 7, 7, 384)    0           ['concatenate_51[0][0]',
#                                                                   'conv2d_56[0][0]']
#
#  batch_normalization_57 (BatchN  (None, 7, 7, 384)   1536        ['concatenate_52[0][0]']
#  ormalization)
#
#  activation_57 (Activation)     (None, 7, 7, 384)    0           ['batch_normalization_57[0][0]']
#
#  conv2d_57 (Conv2D)             (None, 7, 7, 32)     110624      ['activation_57[0][0]']
#
#  concatenate_53 (Concatenate)   (None, 7, 7, 416)    0           ['concatenate_52[0][0]',
#                                                                   'conv2d_57[0][0]']
#
#  batch_normalization_58 (BatchN  (None, 7, 7, 416)   1664        ['concatenate_53[0][0]']
#  ormalization)
#
#  activation_58 (Activation)     (None, 7, 7, 416)    0           ['batch_normalization_58[0][0]']
#
#  conv2d_58 (Conv2D)             (None, 7, 7, 32)     119840      ['activation_58[0][0]']
#
#  concatenate_54 (Concatenate)   (None, 7, 7, 448)    0           ['concatenate_53[0][0]',
#                                                                   'conv2d_58[0][0]']
#
#  batch_normalization_59 (BatchN  (None, 7, 7, 448)   1792        ['concatenate_54[0][0]']
#  ormalization)
#
#  activation_59 (Activation)     (None, 7, 7, 448)    0           ['batch_normalization_59[0][0]']
#
#  conv2d_59 (Conv2D)             (None, 7, 7, 32)     129056      ['activation_59[0][0]']
#
#  concatenate_55 (Concatenate)   (None, 7, 7, 480)    0           ['concatenate_54[0][0]',
#                                                                   'conv2d_59[0][0]']
#
#  batch_normalization_60 (BatchN  (None, 7, 7, 480)   1920        ['concatenate_55[0][0]']
#  ormalization)
#
#  activation_60 (Activation)     (None, 7, 7, 480)    0           ['batch_normalization_60[0][0]']
#
#  conv2d_60 (Conv2D)             (None, 7, 7, 32)     138272      ['activation_60[0][0]']
#
#  concatenate_56 (Concatenate)   (None, 7, 7, 512)    0           ['concatenate_55[0][0]',
#                                                                   'conv2d_60[0][0]']
#
#  batch_normalization_61 (BatchN  (None, 7, 7, 512)   2048        ['concatenate_56[0][0]']
#  ormalization)
#
#  activation_61 (Activation)     (None, 7, 7, 512)    0           ['batch_normalization_61[0][0]']
#
#  conv2d_61 (Conv2D)             (None, 7, 7, 32)     147488      ['activation_61[0][0]']
#
#  concatenate_57 (Concatenate)   (None, 7, 7, 544)    0           ['concatenate_56[0][0]',
#                                                                   'conv2d_61[0][0]']
#
#  batch_normalization_62 (BatchN  (None, 7, 7, 544)   2176        ['concatenate_57[0][0]']
#  ormalization)
#
#  activation_62 (Activation)     (None, 7, 7, 544)    0           ['batch_normalization_62[0][0]']
#
#  global_average_pooling2d (Glob  (None, 544)         0           ['activation_62[0][0]']
#  alAveragePooling2D)
#
#  dense (Dense)                  (None, 4)            2180        ['global_average_pooling2d[0][0]'
#                                                                  ]
#
# ==================================================================================================
# Total params: 5,124,132
# Trainable params: 5,085,348
# Non-trainable params: 38,784
# __________________________________________________________________________________________________

# %%
# Fit the model and store the history
history = model.fit(
    train_generator,
    steps_per_epoch=num_train_samples // batch_size,
    epochs=num_epoch,
    validation_data=validation_generator,
    validation_steps=num_validation_samples // batch_size
)
# Out:
# Epoch 1/30
# 400/400 [==============================] - 753s 2s/step - loss: 0.8806 - accuracy: 0.6348 - val_loss: 2.1633 - val_accuracy: 0.2955
# Epoch 2/30
# 400/400 [==============================] - 142s 354ms/step - loss: 0.6889 - accuracy: 0.7281 - val_loss: 1.1767 - val_accuracy: 0.6260
# Epoch 3/30
# 400/400 [==============================] - 139s 347ms/step - loss: 0.5632 - accuracy: 0.7768 - val_loss: 0.7183 - val_accuracy: 0.7095
# Epoch 4/30
# 400/400 [==============================] - 141s 353ms/step - loss: 0.4753 - accuracy: 0.8188 - val_loss: 1.2706 - val_accuracy: 0.6355
# Epoch 5/30
# 400/400 [==============================] - 139s 348ms/step - loss: 0.3808 - accuracy: 0.8572 - val_loss: 0.8421 - val_accuracy: 0.7320
# Epoch 6/30
# 400/400 [==============================] - 141s 352ms/step - loss: 0.3304 - accuracy: 0.8804 - val_loss: 0.3124 - val_accuracy: 0.8875
# Epoch 7/30
# 400/400 [==============================] - 139s 348ms/step - loss: 0.2937 - accuracy: 0.8934 - val_loss: 0.5629 - val_accuracy: 0.7805
# Epoch 8/30
# 400/400 [==============================] - 140s 350ms/step - loss: 0.2470 - accuracy: 0.9124 - val_loss: 0.6325 - val_accuracy: 0.7860
# Epoch 9/30
# 400/400 [==============================] - 136s 340ms/step - loss: 0.2327 - accuracy: 0.9162 - val_loss: 0.5720 - val_accuracy: 0.8275
# Epoch 10/30
# 400/400 [==============================] - 137s 342ms/step - loss: 0.2137 - accuracy: 0.9211 - val_loss: 0.1979 - val_accuracy: 0.9240
# Epoch 11/30
# 400/400 [==============================] - 138s 343ms/step - loss: 0.1911 - accuracy: 0.9334 - val_loss: 0.5162 - val_accuracy: 0.8505
# Epoch 12/30
# 400/400 [==============================] - 139s 347ms/step - loss: 0.1743 - accuracy: 0.9360 - val_loss: 0.1588 - val_accuracy: 0.9510
# Epoch 13/30
# 400/400 [==============================] - 138s 344ms/step - loss: 0.1615 - accuracy: 0.9434 - val_loss: 0.8044 - val_accuracy: 0.7090
# Epoch 14/30
# 400/400 [==============================] - 139s 347ms/step - loss: 0.1506 - accuracy: 0.9499 - val_loss: 0.2368 - val_accuracy: 0.9175
# Epoch 15/30
# 400/400 [==============================] - 138s 344ms/step - loss: 0.1362 - accuracy: 0.9510 - val_loss: 0.4250 - val_accuracy: 0.8610
# Epoch 16/30
# 400/400 [==============================] - 142s 353ms/step - loss: 0.1397 - accuracy: 0.9505 - val_loss: 0.5235 - val_accuracy: 0.8690
# Epoch 17/30
# 400/400 [==============================] - 140s 351ms/step - loss: 0.1245 - accuracy: 0.9566 - val_loss: 0.2611 - val_accuracy: 0.9105
# Epoch 18/30
# 400/400 [==============================] - 140s 351ms/step - loss: 0.1251 - accuracy: 0.9563 - val_loss: 0.4165 - val_accuracy: 0.8765
# Epoch 19/30
# 400/400 [==============================] - 138s 344ms/step - loss: 0.1105 - accuracy: 0.9620 - val_loss: 0.0809 - val_accuracy: 0.9700
# Epoch 20/30
# 400/400 [==============================] - 141s 352ms/step - loss: 0.1169 - accuracy: 0.9570 - val_loss: 0.3113 - val_accuracy: 0.8900
# Epoch 21/30
# 400/400 [==============================] - 136s 341ms/step - loss: 0.1079 - accuracy: 0.9617 - val_loss: 0.1687 - val_accuracy: 0.9475
# Epoch 22/30
# 400/400 [==============================] - 138s 345ms/step - loss: 0.0980 - accuracy: 0.9659 - val_loss: 0.1099 - val_accuracy: 0.9615
# Epoch 23/30
# 400/400 [==============================] - 136s 341ms/step - loss: 0.0916 - accuracy: 0.9693 - val_loss: 0.0978 - val_accuracy: 0.9720
# Epoch 24/30
# 400/400 [==============================] - 138s 345ms/step - loss: 0.0982 - accuracy: 0.9661 - val_loss: 0.5597 - val_accuracy: 0.8355
# Epoch 25/30
# 400/400 [==============================] - 138s 345ms/step - loss: 0.0900 - accuracy: 0.9678 - val_loss: 0.1180 - val_accuracy: 0.9605
# Epoch 26/30
# 400/400 [==============================] - 138s 344ms/step - loss: 0.0868 - accuracy: 0.9694 - val_loss: 0.0776 - val_accuracy: 0.9775
# Epoch 27/30
# 400/400 [==============================] - 137s 343ms/step - loss: 0.0812 - accuracy: 0.9719 - val_loss: 0.1516 - val_accuracy: 0.9510
# Epoch 28/30
# 400/400 [==============================] - 136s 339ms/step - loss: 0.0841 - accuracy: 0.9722 - val_loss: 0.1344 - val_accuracy: 0.9580
# Epoch 29/30
# 400/400 [==============================] - 138s 345ms/step - loss: 0.0737 - accuracy: 0.9761 - val_loss: 0.0895 - val_accuracy: 0.9685
# Epoch 30/30
# 400/400 [==============================] - 136s 340ms/step - loss: 0.0724 - accuracy: 0.9740 - val_loss: 0.1374 - val_accuracy: 0.9610

# %%
# Plot training accuracy graph
epochs = range(1, num_epoch + 1)
train_acc = model.history.history['accuracy']  # Use 'accuracy' instead of 'acc'
plt.plot(epochs, train_acc, 'b', label='Training Accuracy')
plt.title('Training Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

# Plot validation accuracy graph
val_acc = model.history.history['val_accuracy']  # Use 'val_accuracy' instead of 'val_acc'
plt.plot(epochs, val_acc, 'r', label='Validation Accuracy')
plt.title('Validation Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

# Plot training and validation accuracy graph together
plt.plot(epochs, train_acc, 'b', label='Training Accuracy')
plt.plot(epochs, val_acc, 'r', label='Validation Accuracy')
plt.title('Training and Validation Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

# %%
import matplotlib.pyplot as plt
import matplotlib.font_manager as fm
from matplotlib.font_manager import FontProperties
import numpy as np
import matplotlib.pyplot as plt
from sklearn.metrics import accuracy_score, f1_score, confusion_matrix
import itertools  # Import itertools module

# Generate predictions
y_train_pred = model.predict(train_generator)
y_val_pred = model.predict(validation_generator)

# Get true labels
y_train_true = train_generator.classes
y_val_true = validation_generator.classes

# Calculate accuracy
val_accuracy = accuracy_score(y_val_true, np.argmax(y_val_pred, axis=1))

# Calculate F1 score
train_f1_score = f1_score(y_train_true, np.argmax(y_train_pred, axis=1), average='weighted')
val_f1_score = f1_score(y_val_true, np.argmax(y_val_pred, axis=1), average='weighted')

print("Validation Accuracy: {:.2f}%".format(val_accuracy * 100))
print("Validation F1 Score: {:.2f}".format(val_f1_score))
# Out:
# 400/400 [==============================] - 116s 286ms/step
# 100/100 [==============================] - 8s 75ms/step
# Validation Accuracy: 96.10%
# Validation F1 Score: 0.96

# %%
# Confusion matrix
val_cm = confusion_matrix(y_val_true, np.argmax(y_val_pred, axis=1))

# Plot confusion matrix
def plot_confusion_matrix(cm, classes, normalize=False, title='Confusion matrix', cmap=plt.cm.BuGn):
    """
    This function prints and plots the confusion matrix.
    Normalization can be applied by setting `normalize=True`.
    """
    plt.figure(figsize=(6, 6))
    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation=45)
    plt.yticks(tick_marks, classes)

    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
        print("Normalized confusion matrix")
    else:
        print('Confusion matrix, without normalization')

    print(cm)

    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, cm[i, j],
                 horizontalalignment="center",
                 color="white" if cm[i, j] > thresh else "black")
    plt.tight_layout()
    plt.ylabel('True label')
    plt.xlabel('Predicted label')
    plt.tight_layout()

class_names = train_generator.class_indices.keys()
plot_confusion_matrix(val_cm, classes=class_names, title='Validation Confusion Matrix')
# Out:
# Confusion matrix, without normalization
# [[463  20  16   1]
#  [  1 479  20   0]
#  [  0   0 500   0]
#  [  2  14   4 480]]

# %%
import seaborn as sns
#  "Accuracy"
plt.figure(figsize=[8, 4])
sns.set_theme()
plt.plot(history.history['accuracy'], 'o-', color="Green")
plt.plot(history.history['val_accuracy'] , 'o-', color="Red")
plt.title('Model Accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='lower right')
#plt.show()
plt.gca().set_position([0.1, 0.12, 0.8, 0.8])
# "Loss"
plt.figure(figsize=[8, 4])
sns.set_theme()
plt.plot(history.history['loss'], 'o-', color="Green")
plt.plot(history.history['val_loss'], 'o-', color="Red")
plt.title('Model Loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper right')
#plt.show()
plt.gca().set_position([0.1, 0.12, 0.8, 0.8])

# %%
from tensorflow.keras import layers, models

def dense_block(x, blocks, growth_rate):
    for _ in range(blocks):
        x1 = layers.BatchNormalization()(x)
        x1 = layers.Activation('relu')(x1)
        x1 = layers.Conv2D(growth_rate, (3, 3), padding='same')(x1)
        x = layers.concatenate([x, x1], axis=-1)
    return x

def transition_block(x, compression_factor):
    x = layers.BatchNormalization()(x)
    x = layers.Activation('relu')(x)
    x = layers.Conv2D(int(x.shape[-1] * compression_factor), (1, 1), padding='same')(x)
    x = layers.AveragePooling2D((2, 2), strides=(2, 2))(x)
    return x

def dense_net(input_shape, num_classes, blocks_per_dense_block=[6, 12, 24, 16], growth_rate=32, compression_factor=0.5):
    inputs = layers.Input(shape=input_shape)
    x = layers.Conv2D(64, (7, 7), strides=(2, 2), padding='same')(inputs)
    x = layers.BatchNormalization()(x)
    x = layers.Activation('relu')(x)
    x = layers.MaxPooling2D((3, 3), strides=(2, 2), padding='same')(x)

    for blocks in blocks_per_dense_block:
        x = dense_block(x, blocks, growth_rate)
        if blocks != blocks_per_dense_block[-1]:
            x = transition_block(x, compression_factor)

    x = layers.BatchNormalization()(x)
    x = layers.Activation('relu')(x)
    x = layers.GlobalAveragePooling2D()(x)
    outputs = layers.Dense(num_classes, activation='softmax')(x)

    model = models.Model(inputs, outputs)
    return model

input_shape = (224, 224, 3)
num_classes = 4
model = dense_net(input_shape, num_classes)

model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 224, 224, 3  0           []
#                                 )]
#
#  conv2d (Conv2D)                (None, 112, 112, 64  9472        ['input_1[0][0]']
#                                 )
#
#  batch_normalization (BatchNorm  (None, 112, 112, 64  256        ['conv2d[0][0]']
#  alization)                     )
#
#  activation (Activation)        (None, 112, 112, 64  0           ['batch_normalization[0][0]']
#                                 )
#
#  max_pooling2d (MaxPooling2D)   (None, 56, 56, 64)   0           ['activation[0][0]']
#
#  batch_normalization_1 (BatchNo  (None, 56, 56, 64)  256         ['max_pooling2d[0][0]']
#  rmalization)
#
#  activation_1 (Activation)      (None, 56, 56, 64)   0           ['batch_normalization_1[0][0]']
#
#  conv2d_1 (Conv2D)              (None, 56, 56, 32)   18464       ['activation_1[0][0]']
#
#  concatenate (Concatenate)      (None, 56, 56, 96)   0           ['max_pooling2d[0][0]',
#                                                                   'conv2d_1[0][0]']
#
#  batch_normalization_2 (BatchNo  (None, 56, 56, 96)  384         ['concatenate[0][0]']
#  rmalization)
#
#  activation_2 (Activation)      (None, 56, 56, 96)   0           ['batch_normalization_2[0][0]']
#
#  conv2d_2 (Conv2D)              (None, 56, 56, 32)   27680       ['activation_2[0][0]']
#
#  concatenate_1 (Concatenate)    (None, 56, 56, 128)  0           ['concatenate[0][0]',
#                                                                   'conv2d_2[0][0]']
#
#  batch_normalization_3 (BatchNo  (None, 56, 56, 128)  512        ['concatenate_1[0][0]']
#  rmalization)
#
#  activation_3 (Activation)      (None, 56, 56, 128)  0           ['batch_normalization_3[0][0]']
#
#  conv2d_3 (Conv2D)              (None, 56, 56, 32)   36896       ['activation_3[0][0]']
#
#  concatenate_2 (Concatenate)    (None, 56, 56, 160)  0           ['concatenate_1[0][0]',
#                                                                   'conv2d_3[0][0]']
#
#  batch_normalization_4 (BatchNo  (None, 56, 56, 160)  640        ['concatenate_2[0][0]']
#  rmalization)
#
#  activation_4 (Activation)      (None, 56, 56, 160)  0           ['batch_normalization_4[0][0]']
#
#  conv2d_4 (Conv2D)              (None, 56, 56, 32)   46112       ['activation_4[0][0]']
#
#  concatenate_3 (Concatenate)    (None, 56, 56, 192)  0           ['concatenate_2[0][0]',
#                                                                   'conv2d_4[0][0]']
#
#  batch_normalization_5 (BatchNo  (None, 56, 56, 192)  768        ['concatenate_3[0][0]']
#  rmalization)
#
#  activation_5 (Activation)      (None, 56, 56, 192)  0           ['batch_normalization_5[0][0]']
#
#  conv2d_5 (Conv2D)              (None, 56, 56, 32)   55328       ['activation_5[0][0]']
#
#  concatenate_4 (Concatenate)    (None, 56, 56, 224)  0           ['concatenate_3[0][0]',
#                                                                   'conv2d_5[0][0]']
#
#  batch_normalization_6 (BatchNo  (None, 56, 56, 224)  896        ['concatenate_4[0][0]']
#  rmalization)
#
#  activation_6 (Activation)      (None, 56, 56, 224)  0           ['batch_normalization_6[0][0]']
#
#  conv2d_6 (Conv2D)              (None, 56, 56, 32)   64544       ['activation_6[0][0]']
#
#  concatenate_5 (Concatenate)    (None, 56, 56, 256)  0           ['concatenate_4[0][0]',
#                                                                   'conv2d_6[0][0]']
#
#  batch_normalization_7 (BatchNo  (None, 56, 56, 256)  1024       ['concatenate_5[0][0]']
#  rmalization)
#
#  activation_7 (Activation)      (None, 56, 56, 256)  0           ['batch_normalization_7[0][0]']
#
#  conv2d_7 (Conv2D)              (None, 56, 56, 128)  32896       ['activation_7[0][0]']
#
#  average_pooling2d (AveragePool  (None, 28, 28, 128)  0          ['conv2d_7[0][0]']
#  ing2D)
#
#  batch_normalization_8 (BatchNo  (None, 28, 28, 128)  512        ['average_pooling2d[0][0]']
#  rmalization)
#
#  activation_8 (Activation)      (None, 28, 28, 128)  0           ['batch_normalization_8[0][0]']
#
#  conv2d_8 (Conv2D)              (None, 28, 28, 32)   36896       ['activation_8[0][0]']
#
#  concatenate_6 (Concatenate)    (None, 28, 28, 160)  0           ['average_pooling2d[0][0]',
#                                                                   'conv2d_8[0][0]']
#
#  batch_normalization_9 (BatchNo  (None, 28, 28, 160)  640        ['concatenate_6[0][0]']
#  rmalization)
#
#  activation_9 (Activation)      (None, 28, 28, 160)  0           ['batch_normalization_9[0][0]']
#
#  conv2d_9 (Conv2D)              (None, 28, 28, 32)   46112       ['activation_9[0][0]']
#
#  concatenate_7 (Concatenate)    (None, 28, 28, 192)  0           ['concatenate_6[0][0]',
#                                                                   'conv2d_9[0][0]']
#
#  batch_normalization_10 (BatchN  (None, 28, 28, 192)  768        ['concatenate_7[0][0]']
#  ormalization)
#
#  activation_10 (Activation)     (None, 28, 28, 192)  0           ['batch_normalization_10[0][0]']
#
#  conv2d_10 (Conv2D)             (None, 28, 28, 32)   55328       ['activation_10[0][0]']
#
#  concatenate_8 (Concatenate)    (None, 28, 28, 224)  0           ['concatenate_7[0][0]',
#                                                                   'conv2d_10[0][0]']
#
#  batch_normalization_11 (BatchN  (None, 28, 28, 224)  896        ['concatenate_8[0][0]']
#  ormalization)
#
#  activation_11 (Activation)     (None, 28, 28, 224)  0           ['batch_normalization_11[0][0]']
#
#  conv2d_11 (Conv2D)             (None, 28, 28, 32)   64544       ['activation_11[0][0]']
#
#  concatenate_9 (Concatenate)    (None, 28, 28, 256)  0           ['concatenate_8[0][0]',
#                                                                   'conv2d_11[0][0]']
#
#  batch_normalization_12 (BatchN  (None, 28, 28, 256)  1024       ['concatenate_9[0][0]']
#  ormalization)
#
#  activation_12 (Activation)     (None, 28, 28, 256)  0           ['batch_normalization_12[0][0]']
#
#  conv2d_12 (Conv2D)             (None, 28, 28, 32)   73760       ['activation_12[0][0]']
#
#  concatenate_10 (Concatenate)   (None, 28, 28, 288)  0           ['concatenate_9[0][0]',
#                                                                   'conv2d_12[0][0]']
#
#  batch_normalization_13 (BatchN  (None, 28, 28, 288)  1152       ['concatenate_10[0][0]']
#  ormalization)
#
#  activation_13 (Activation)     (None, 28, 28, 288)  0           ['batch_normalization_13[0][0]']
#
#  conv2d_13 (Conv2D)             (None, 28, 28, 32)   82976       ['activation_13[0][0]']
#
#  concatenate_11 (Concatenate)   (None, 28, 28, 320)  0           ['concatenate_10[0][0]',
#                                                                   'conv2d_13[0][0]']
#
#  batch_normalization_14 (BatchN  (None, 28, 28, 320)  1280       ['concatenate_11[0][0]']
#  ormalization)
#
#  activation_14 (Activation)     (None, 28, 28, 320)  0           ['batch_normalization_14[0][0]']
#
#  conv2d_14 (Conv2D)             (None, 28, 28, 32)   92192       ['activation_14[0][0]']
#
#  concatenate_12 (Concatenate)   (None, 28, 28, 352)  0           ['concatenate_11[0][0]',
#                                                                   'conv2d_14[0][0]']
#
#  batch_normalization_15 (BatchN  (None, 28, 28, 352)  1408       ['concatenate_12[0][0]']
#  ormalization)
#
#  activation_15 (Activation)     (None, 28, 28, 352)  0           ['batch_normalization_15[0][0]']
#
#  conv2d_15 (Conv2D)             (None, 28, 28, 32)   101408      ['activation_15[0][0]']
#
#  concatenate_13 (Concatenate)   (None, 28, 28, 384)  0           ['concatenate_12[0][0]',
#                                                                   'conv2d_15[0][0]']
#
#  batch_normalization_16 (BatchN  (None, 28, 28, 384)  1536       ['concatenate_13[0][0]']
#  ormalization)
#
#  activation_16 (Activation)     (None, 28, 28, 384)  0           ['batch_normalization_16[0][0]']
#
#  conv2d_16 (Conv2D)             (None, 28, 28, 32)   110624      ['activation_16[0][0]']
#
#  concatenate_14 (Concatenate)   (None, 28, 28, 416)  0           ['concatenate_13[0][0]',
#                                                                   'conv2d_16[0][0]']
#
#  batch_normalization_17 (BatchN  (None, 28, 28, 416)  1664       ['concatenate_14[0][0]']
#  ormalization)
#
#  activation_17 (Activation)     (None, 28, 28, 416)  0           ['batch_normalization_17[0][0]']
#
#  conv2d_17 (Conv2D)             (None, 28, 28, 32)   119840      ['activation_17[0][0]']
#
#  concatenate_15 (Concatenate)   (None, 28, 28, 448)  0           ['concatenate_14[0][0]',
#                                                                   'conv2d_17[0][0]']
#
#  batch_normalization_18 (BatchN  (None, 28, 28, 448)  1792       ['concatenate_15[0][0]']
#  ormalization)
#
#  activation_18 (Activation)     (None, 28, 28, 448)  0           ['batch_normalization_18[0][0]']
#
#  conv2d_18 (Conv2D)             (None, 28, 28, 32)   129056      ['activation_18[0][0]']
#
#  concatenate_16 (Concatenate)   (None, 28, 28, 480)  0           ['concatenate_15[0][0]',
#                                                                   'conv2d_18[0][0]']
#
#  batch_normalization_19 (BatchN  (None, 28, 28, 480)  1920       ['concatenate_16[0][0]']
#  ormalization)
#
#  activation_19 (Activation)     (None, 28, 28, 480)  0           ['batch_normalization_19[0][0]']
#
#  conv2d_19 (Conv2D)             (None, 28, 28, 32)   138272      ['activation_19[0][0]']
#
#  concatenate_17 (Concatenate)   (None, 28, 28, 512)  0           ['concatenate_16[0][0]',
#                                                                   'conv2d_19[0][0]']
#
#  batch_normalization_20 (BatchN  (None, 28, 28, 512)  2048       ['concatenate_17[0][0]']
#  ormalization)
#
#  activation_20 (Activation)     (None, 28, 28, 512)  0           ['batch_normalization_20[0][0]']
#
#  conv2d_20 (Conv2D)             (None, 28, 28, 256)  131328      ['activation_20[0][0]']
#
#  average_pooling2d_1 (AveragePo  (None, 14, 14, 256)  0          ['conv2d_20[0][0]']
#  oling2D)
#
#  batch_normalization_21 (BatchN  (None, 14, 14, 256)  1024       ['average_pooling2d_1[0][0]']
#  ormalization)
#
#  activation_21 (Activation)     (None, 14, 14, 256)  0           ['batch_normalization_21[0][0]']
#
#  conv2d_21 (Conv2D)             (None, 14, 14, 32)   73760       ['activation_21[0][0]']
#
#  concatenate_18 (Concatenate)   (None, 14, 14, 288)  0           ['average_pooling2d_1[0][0]',
#                                                                   'conv2d_21[0][0]']
#
#  batch_normalization_22 (BatchN  (None, 14, 14, 288)  1152       ['concatenate_18[0][0]']
#  ormalization)
#
#  activation_22 (Activation)     (None, 14, 14, 288)  0           ['batch_normalization_22[0][0]']
#
#  conv2d_22 (Conv2D)             (None, 14, 14, 32)   82976       ['activation_22[0][0]']
#
#  concatenate_19 (Concatenate)   (None, 14, 14, 320)  0           ['concatenate_18[0][0]',
#                                                                   'conv2d_22[0][0]']
#
#  batch_normalization_23 (BatchN  (None, 14, 14, 320)  1280       ['concatenate_19[0][0]']
#  ormalization)
#
#  activation_23 (Activation)     (None, 14, 14, 320)  0           ['batch_normalization_23[0][0]']
#
#  conv2d_23 (Conv2D)             (None, 14, 14, 32)   92192       ['activation_23[0][0]']
#
#  concatenate_20 (Concatenate)   (None, 14, 14, 352)  0           ['concatenate_19[0][0]',
#                                                                   'conv2d_23[0][0]']
#
#  batch_normalization_24 (BatchN  (None, 14, 14, 352)  1408       ['concatenate_20[0][0]']
#  ormalization)
#
#  activation_24 (Activation)     (None, 14, 14, 352)  0           ['batch_normalization_24[0][0]']
#
#  conv2d_24 (Conv2D)             (None, 14, 14, 32)   101408      ['activation_24[0][0]']
#
#  concatenate_21 (Concatenate)   (None, 14, 14, 384)  0           ['concatenate_20[0][0]',
#                                                                   'conv2d_24[0][0]']
#
#  batch_normalization_25 (BatchN  (None, 14, 14, 384)  1536       ['concatenate_21[0][0]']
#  ormalization)
#
#  activation_25 (Activation)     (None, 14, 14, 384)  0           ['batch_normalization_25[0][0]']
#
#  conv2d_25 (Conv2D)             (None, 14, 14, 32)   110624      ['activation_25[0][0]']
#
#  concatenate_22 (Concatenate)   (None, 14, 14, 416)  0           ['concatenate_21[0][0]',
#                                                                   'conv2d_25[0][0]']
#
#  batch_normalization_26 (BatchN  (None, 14, 14, 416)  1664       ['concatenate_22[0][0]']
#  ormalization)
#
#  activation_26 (Activation)     (None, 14, 14, 416)  0           ['batch_normalization_26[0][0]']
#
#  conv2d_26 (Conv2D)             (None, 14, 14, 32)   119840      ['activation_26[0][0]']
#
#  concatenate_23 (Concatenate)   (None, 14, 14, 448)  0           ['concatenate_22[0][0]',
#                                                                   'conv2d_26[0][0]']
#
#  batch_normalization_27 (BatchN  (None, 14, 14, 448)  1792       ['concatenate_23[0][0]']
#  ormalization)
#
#  activation_27 (Activation)     (None, 14, 14, 448)  0           ['batch_normalization_27[0][0]']
#
#  conv2d_27 (Conv2D)             (None, 14, 14, 32)   129056      ['activation_27[0][0]']
#
#  concatenate_24 (Concatenate)   (None, 14, 14, 480)  0           ['concatenate_23[0][0]',
#                                                                   'conv2d_27[0][0]']
#
#  batch_normalization_28 (BatchN  (None, 14, 14, 480)  1920       ['concatenate_24[0][0]']
#  ormalization)
#
#  activation_28 (Activation)     (None, 14, 14, 480)  0           ['batch_normalization_28[0][0]']
#
#  conv2d_28 (Conv2D)             (None, 14, 14, 32)   138272      ['activation_28[0][0]']
#
#  concatenate_25 (Concatenate)   (None, 14, 14, 512)  0           ['concatenate_24[0][0]',
#                                                                   'conv2d_28[0][0]']
#
#  batch_normalization_29 (BatchN  (None, 14, 14, 512)  2048       ['concatenate_25[0][0]']
#  ormalization)
#
#  activation_29 (Activation)     (None, 14, 14, 512)  0           ['batch_normalization_29[0][0]']
#
#  conv2d_29 (Conv2D)             (None, 14, 14, 32)   147488      ['activation_29[0][0]']
#
#  concatenate_26 (Concatenate)   (None, 14, 14, 544)  0           ['concatenate_25[0][0]',
#                                                                   'conv2d_29[0][0]']
#
#  batch_normalization_30 (BatchN  (None, 14, 14, 544)  2176       ['concatenate_26[0][0]']
#  ormalization)
#
#  activation_30 (Activation)     (None, 14, 14, 544)  0           ['batch_normalization_30[0][0]']
#
#  conv2d_30 (Conv2D)             (None, 14, 14, 32)   156704      ['activation_30[0][0]']
#
#  concatenate_27 (Concatenate)   (None, 14, 14, 576)  0           ['concatenate_26[0][0]',
#                                                                   'conv2d_30[0][0]']
#
#  batch_normalization_31 (BatchN  (None, 14, 14, 576)  2304       ['concatenate_27[0][0]']
#  ormalization)
#
#  activation_31 (Activation)     (None, 14, 14, 576)  0           ['batch_normalization_31[0][0]']
#
#  conv2d_31 (Conv2D)             (None, 14, 14, 32)   165920      ['activation_31[0][0]']
#
#  concatenate_28 (Concatenate)   (None, 14, 14, 608)  0           ['concatenate_27[0][0]',
#                                                                   'conv2d_31[0][0]']
#
#  batch_normalization_32 (BatchN  (None, 14, 14, 608)  2432       ['concatenate_28[0][0]']
#  ormalization)
#
#  activation_32 (Activation)     (None, 14, 14, 608)  0           ['batch_normalization_32[0][0]']
#
#  conv2d_32 (Conv2D)             (None, 14, 14, 32)   175136      ['activation_32[0][0]']
#
#  concatenate_29 (Concatenate)   (None, 14, 14, 640)  0           ['concatenate_28[0][0]',
#                                                                   'conv2d_32[0][0]']
#
#  batch_normalization_33 (BatchN  (None, 14, 14, 640)  2560       ['concatenate_29[0][0]']
#  ormalization)
#
#  activation_33 (Activation)     (None, 14, 14, 640)  0           ['batch_normalization_33[0][0]']
#
#  conv2d_33 (Conv2D)             (None, 14, 14, 32)   184352      ['activation_33[0][0]']
#
#  concatenate_30 (Concatenate)   (None, 14, 14, 672)  0           ['concatenate_29[0][0]',
#                                                                   'conv2d_33[0][0]']
#
#  batch_normalization_34 (BatchN  (None, 14, 14, 672)  2688       ['concatenate_30[0][0]']
#  ormalization)
#
#  activation_34 (Activation)     (None, 14, 14, 672)  0           ['batch_normalization_34[0][0]']
#
#  conv2d_34 (Conv2D)             (None, 14, 14, 32)   193568      ['activation_34[0][0]']
#
#  concatenate_31 (Concatenate)   (None, 14, 14, 704)  0           ['concatenate_30[0][0]',
#                                                                   'conv2d_34[0][0]']
#
#  batch_normalization_35 (BatchN  (None, 14, 14, 704)  2816       ['concatenate_31[0][0]']
#  ormalization)
#
#  activation_35 (Activation)     (None, 14, 14, 704)  0           ['batch_normalization_35[0][0]']
#
#  conv2d_35 (Conv2D)             (None, 14, 14, 32)   202784      ['activation_35[0][0]']
#
#  concatenate_32 (Concatenate)   (None, 14, 14, 736)  0           ['concatenate_31[0][0]',
#                                                                   'conv2d_35[0][0]']
#
#  batch_normalization_36 (BatchN  (None, 14, 14, 736)  2944       ['concatenate_32[0][0]']
#  ormalization)
#
#  activation_36 (Activation)     (None, 14, 14, 736)  0           ['batch_normalization_36[0][0]']
#
#  conv2d_36 (Conv2D)             (None, 14, 14, 32)   212000      ['activation_36[0][0]']
#
#  concatenate_33 (Concatenate)   (None, 14, 14, 768)  0           ['concatenate_32[0][0]',
#                                                                   'conv2d_36[0][0]']
#
#  batch_normalization_37 (BatchN  (None, 14, 14, 768)  3072       ['concatenate_33[0][0]']
#  ormalization)
#
#  activation_37 (Activation)     (None, 14, 14, 768)  0           ['batch_normalization_37[0][0]']
#
#  conv2d_37 (Conv2D)             (None, 14, 14, 32)   221216      ['activation_37[0][0]']
#
#  concatenate_34 (Concatenate)   (None, 14, 14, 800)  0           ['concatenate_33[0][0]',
#                                                                   'conv2d_37[0][0]']
#
#  batch_normalization_38 (BatchN  (None, 14, 14, 800)  3200       ['concatenate_34[0][0]']
#  ormalization)
#
#  activation_38 (Activation)     (None, 14, 14, 800)  0           ['batch_normalization_38[0][0]']
#
#  conv2d_38 (Conv2D)             (None, 14, 14, 32)   230432      ['activation_38[0][0]']
#
#  concatenate_35 (Concatenate)   (None, 14, 14, 832)  0           ['concatenate_34[0][0]',
#                                                                   'conv2d_38[0][0]']
#
#  batch_normalization_39 (BatchN  (None, 14, 14, 832)  3328       ['concatenate_35[0][0]']
#  ormalization)
#
#  activation_39 (Activation)     (None, 14, 14, 832)  0           ['batch_normalization_39[0][0]']
#
#  conv2d_39 (Conv2D)             (None, 14, 14, 32)   239648      ['activation_39[0][0]']
#
#  concatenate_36 (Concatenate)   (None, 14, 14, 864)  0           ['concatenate_35[0][0]',
#                                                                   'conv2d_39[0][0]']
#
#  batch_normalization_40 (BatchN  (None, 14, 14, 864)  3456       ['concatenate_36[0][0]']
#  ormalization)
#
#  activation_40 (Activation)     (None, 14, 14, 864)  0           ['batch_normalization_40[0][0]']
#
#  conv2d_40 (Conv2D)             (None, 14, 14, 32)   248864      ['activation_40[0][0]']
#
#  concatenate_37 (Concatenate)   (None, 14, 14, 896)  0           ['concatenate_36[0][0]',
#                                                                   'conv2d_40[0][0]']
#
#  batch_normalization_41 (BatchN  (None, 14, 14, 896)  3584       ['concatenate_37[0][0]']
#  ormalization)
#
#  activation_41 (Activation)     (None, 14, 14, 896)  0           ['batch_normalization_41[0][0]']
#
#  conv2d_41 (Conv2D)             (None, 14, 14, 32)   258080      ['activation_41[0][0]']
#
#  concatenate_38 (Concatenate)   (None, 14, 14, 928)  0           ['concatenate_37[0][0]',
#                                                                   'conv2d_41[0][0]']
#
#  batch_normalization_42 (BatchN  (None, 14, 14, 928)  3712       ['concatenate_38[0][0]']
#  ormalization)
#
#  activation_42 (Activation)     (None, 14, 14, 928)  0           ['batch_normalization_42[0][0]']
#
#  conv2d_42 (Conv2D)             (None, 14, 14, 32)   267296      ['activation_42[0][0]']
#
#  concatenate_39 (Concatenate)   (None, 14, 14, 960)  0           ['concatenate_38[0][0]',
#                                                                   'conv2d_42[0][0]']
#
#  batch_normalization_43 (BatchN  (None, 14, 14, 960)  3840       ['concatenate_39[0][0]']
#  ormalization)
#
#  activation_43 (Activation)     (None, 14, 14, 960)  0           ['batch_normalization_43[0][0]']
#
#  conv2d_43 (Conv2D)             (None, 14, 14, 32)   276512      ['activation_43[0][0]']
#
#  concatenate_40 (Concatenate)   (None, 14, 14, 992)  0           ['concatenate_39[0][0]',
#                                                                   'conv2d_43[0][0]']
#
#  batch_normalization_44 (BatchN  (None, 14, 14, 992)  3968       ['concatenate_40[0][0]']
#  ormalization)
#
#  activation_44 (Activation)     (None, 14, 14, 992)  0           ['batch_normalization_44[0][0]']
#
#  conv2d_44 (Conv2D)             (None, 14, 14, 32)   285728      ['activation_44[0][0]']
#
#  concatenate_41 (Concatenate)   (None, 14, 14, 1024  0           ['concatenate_40[0][0]',
#                                 )                                 'conv2d_44[0][0]']
#
#  batch_normalization_45 (BatchN  (None, 14, 14, 1024  4096       ['concatenate_41[0][0]']
#  ormalization)                  )
#
#  activation_45 (Activation)     (None, 14, 14, 1024  0           ['batch_normalization_45[0][0]']
#                                 )
#
#  conv2d_45 (Conv2D)             (None, 14, 14, 512)  524800      ['activation_45[0][0]']
#
#  average_pooling2d_2 (AveragePo  (None, 7, 7, 512)   0           ['conv2d_45[0][0]']
#  oling2D)
#
#  batch_normalization_46 (BatchN  (None, 7, 7, 512)   2048        ['average_pooling2d_2[0][0]']
#  ormalization)
#
#  activation_46 (Activation)     (None, 7, 7, 512)    0           ['batch_normalization_46[0][0]']
#
#  conv2d_46 (Conv2D)             (None, 7, 7, 32)     147488      ['activation_46[0][0]']
#
#  concatenate_42 (Concatenate)   (None, 7, 7, 544)    0           ['average_pooling2d_2[0][0]',
#                                                                   'conv2d_46[0][0]']
#
#  batch_normalization_47 (BatchN  (None, 7, 7, 544)   2176        ['concatenate_42[0][0]']
#  ormalization)
#
#  activation_47 (Activation)     (None, 7, 7, 544)    0           ['batch_normalization_47[0][0]']
#
#  conv2d_47 (Conv2D)             (None, 7, 7, 32)     156704      ['activation_47[0][0]']
#
#  concatenate_43 (Concatenate)   (None, 7, 7, 576)    0           ['concatenate_42[0][0]',
#                                                                   'conv2d_47[0][0]']
#
#  batch_normalization_48 (BatchN  (None, 7, 7, 576)   2304        ['concatenate_43[0][0]']
#  ormalization)
#
#  activation_48 (Activation)     (None, 7, 7, 576)    0           ['batch_normalization_48[0][0]']
#
#  conv2d_48 (Conv2D)             (None, 7, 7, 32)     165920      ['activation_48[0][0]']
#
#  concatenate_44 (Concatenate)   (None, 7, 7, 608)    0           ['concatenate_43[0][0]',
#                                                                   'conv2d_48[0][0]']
#
#  batch_normalization_49 (BatchN  (None, 7, 7, 608)   2432        ['concatenate_44[0][0]']
#  ormalization)
#
#  activation_49 (Activation)     (None, 7, 7, 608)    0           ['batch_normalization_49[0][0]']
#
#  conv2d_49 (Conv2D)             (None, 7, 7, 32)     175136      ['activation_49[0][0]']
#
#  concatenate_45 (Concatenate)   (None, 7, 7, 640)    0           ['concatenate_44[0][0]',
#                                                                   'conv2d_49[0][0]']
#
#  batch_normalization_50 (BatchN  (None, 7, 7, 640)   2560        ['concatenate_45[0][0]']
#  ormalization)
#
#  activation_50 (Activation)     (None, 7, 7, 640)    0           ['batch_normalization_50[0][0]']
#
#  conv2d_50 (Conv2D)             (None, 7, 7, 32)     184352      ['activation_50[0][0]']
#
#  concatenate_46 (Concatenate)   (None, 7, 7, 672)    0           ['concatenate_45[0][0]',
#                                                                   'conv2d_50[0][0]']
#
#  batch_normalization_51 (BatchN  (None, 7, 7, 672)   2688        ['concatenate_46[0][0]']
#  ormalization)
#
#  activation_51 (Activation)     (None, 7, 7, 672)    0           ['batch_normalization_51[0][0]']
#
#  conv2d_51 (Conv2D)             (None, 7, 7, 32)     193568      ['activation_51[0][0]']
#
#  concatenate_47 (Concatenate)   (None, 7, 7, 704)    0           ['concatenate_46[0][0]',
#                                                                   'conv2d_51[0][0]']
#
#  batch_normalization_52 (BatchN  (None, 7, 7, 704)   2816        ['concatenate_47[0][0]']
#  ormalization)
#
#  activation_52 (Activation)     (None, 7, 7, 704)    0           ['batch_normalization_52[0][0]']
#
#  conv2d_52 (Conv2D)             (None, 7, 7, 32)     202784      ['activation_52[0][0]']
#
#  concatenate_48 (Concatenate)   (None, 7, 7, 736)    0           ['concatenate_47[0][0]',
#                                                                   'conv2d_52[0][0]']
#
#  batch_normalization_53 (BatchN  (None, 7, 7, 736)   2944        ['concatenate_48[0][0]']
#  ormalization)
#
#  activation_53 (Activation)     (None, 7, 7, 736)    0           ['batch_normalization_53[0][0]']
#
#  conv2d_53 (Conv2D)             (None, 7, 7, 32)     212000      ['activation_53[0][0]']
#
#  concatenate_49 (Concatenate)   (None, 7, 7, 768)    0           ['concatenate_48[0][0]',
#                                                                   'conv2d_53[0][0]']
#
#  batch_normalization_54 (BatchN  (None, 7, 7, 768)   3072        ['concatenate_49[0][0]']
#  ormalization)
#
#  activation_54 (Activation)     (None, 7, 7, 768)    0           ['batch_normalization_54[0][0]']
#
#  conv2d_54 (Conv2D)             (None, 7, 7, 32)     221216      ['activation_54[0][0]']
#
#  concatenate_50 (Concatenate)   (None, 7, 7, 800)    0           ['concatenate_49[0][0]',
#                                                                   'conv2d_54[0][0]']
#
#  batch_normalization_55 (BatchN  (None, 7, 7, 800)   3200        ['concatenate_50[0][0]']
#  ormalization)
#
#  activation_55 (Activation)     (None, 7, 7, 800)    0           ['batch_normalization_55[0][0]']
#
#  conv2d_55 (Conv2D)             (None, 7, 7, 32)     230432      ['activation_55[0][0]']
#
#  concatenate_51 (Concatenate)   (None, 7, 7, 832)    0           ['concatenate_50[0][0]',
#                                                                   'conv2d_55[0][0]']
#
#  batch_normalization_56 (BatchN  (None, 7, 7, 832)   3328        ['concatenate_51[0][0]']
#  ormalization)
#
#  activation_56 (Activation)     (None, 7, 7, 832)    0           ['batch_normalization_56[0][0]']
#
#  conv2d_56 (Conv2D)             (None, 7, 7, 32)     239648      ['activation_56[0][0]']
#
#  concatenate_52 (Concatenate)   (None, 7, 7, 864)    0           ['concatenate_51[0][0]',
#                                                                   'conv2d_56[0][0]']
#
#  batch_normalization_57 (BatchN  (None, 7, 7, 864)   3456        ['concatenate_52[0][0]']
#  ormalization)
#
#  activation_57 (Activation)     (None, 7, 7, 864)    0           ['batch_normalization_57[0][0]']
#
#  conv2d_57 (Conv2D)             (None, 7, 7, 32)     248864      ['activation_57[0][0]']
#
#  concatenate_53 (Concatenate)   (None, 7, 7, 896)    0           ['concatenate_52[0][0]',
#                                                                   'conv2d_57[0][0]']
#
#  batch_normalization_58 (BatchN  (None, 7, 7, 896)   3584        ['concatenate_53[0][0]']
#  ormalization)
#
#  activation_58 (Activation)     (None, 7, 7, 896)    0           ['batch_normalization_58[0][0]']
#
#  conv2d_58 (Conv2D)             (None, 7, 7, 32)     258080      ['activation_58[0][0]']
#
#  concatenate_54 (Concatenate)   (None, 7, 7, 928)    0           ['concatenate_53[0][0]',
#                                                                   'conv2d_58[0][0]']
#
#  batch_normalization_59 (BatchN  (None, 7, 7, 928)   3712        ['concatenate_54[0][0]']
#  ormalization)
#
#  activation_59 (Activation)     (None, 7, 7, 928)    0           ['batch_normalization_59[0][0]']
#
#  conv2d_59 (Conv2D)             (None, 7, 7, 32)     267296      ['activation_59[0][0]']
#
#  concatenate_55 (Concatenate)   (None, 7, 7, 960)    0           ['concatenate_54[0][0]',
#                                                                   'conv2d_59[0][0]']
#
#  batch_normalization_60 (BatchN  (None, 7, 7, 960)   3840        ['concatenate_55[0][0]']
#  ormalization)
#
#  activation_60 (Activation)     (None, 7, 7, 960)    0           ['batch_normalization_60[0][0]']
#
#  conv2d_60 (Conv2D)             (None, 7, 7, 32)     276512      ['activation_60[0][0]']
#
#  concatenate_56 (Concatenate)   (None, 7, 7, 992)    0           ['concatenate_55[0][0]',
#                                                                   'conv2d_60[0][0]']
#
#  batch_normalization_61 (BatchN  (None, 7, 7, 992)   3968        ['concatenate_56[0][0]']
#  ormalization)
#
#  activation_61 (Activation)     (None, 7, 7, 992)    0           ['batch_normalization_61[0][0]']
#
#  conv2d_61 (Conv2D)             (None, 7, 7, 32)     285728      ['activation_61[0][0]']
#
#  concatenate_57 (Concatenate)   (None, 7, 7, 1024)   0           ['concatenate_56[0][0]',
#                                                                   'conv2d_61[0][0]']
#
#  batch_normalization_62 (BatchN  (None, 7, 7, 1024)  4096        ['concatenate_57[0][0]']
#  ormalization)
#
#  activation_62 (Activation)     (None, 7, 7, 1024)   0           ['batch_normalization_62[0][0]']
#
#  global_average_pooling2d (Glob  (None, 1024)        0           ['activation_62[0][0]']
#  alAveragePooling2D)
#
#  dense (Dense)                  (None, 4)            4100        ['global_average_pooling2d[0][0]'
#                                                                  ]
#
# ==================================================================================================
# Total params: 9,919,812
# Trainable params: 9,851,012
# Non-trainable params: 68,800
# __________________________________________________________________________________________________

# %%
# Fit the model and store the history
history = model.fit(
    train_generator,
    steps_per_epoch=num_train_samples // batch_size,
    epochs=num_epoch,
    validation_data=validation_generator,
    validation_steps=num_validation_samples // batch_size
)
# Out:
# Epoch 1/30
# 400/400 [==============================] - 702s 2s/step - loss: 0.8627 - accuracy: 0.6528 - val_loss: 3.2805 - val_accuracy: 0.2565
# Epoch 2/30
# 400/400 [==============================] - 166s 414ms/step - loss: 0.6827 - accuracy: 0.7318 - val_loss: 3.6686 - val_accuracy: 0.4445
# Epoch 3/30
# 400/400 [==============================] - 168s 419ms/step - loss: 0.5590 - accuracy: 0.7861 - val_loss: 2.7261 - val_accuracy: 0.4340
# Epoch 4/30
# 400/400 [==============================] - 166s 414ms/step - loss: 0.4801 - accuracy: 0.8174 - val_loss: 3.7823 - val_accuracy: 0.3810
# Epoch 5/30
# 400/400 [==============================] - 163s 406ms/step - loss: 0.4105 - accuracy: 0.8455 - val_loss: 0.3936 - val_accuracy: 0.8585
# Epoch 6/30
# 400/400 [==============================] - 161s 402ms/step - loss: 0.3826 - accuracy: 0.8600 - val_loss: 1.3516 - val_accuracy: 0.6175
# Epoch 7/30
# 400/400 [==============================] - 163s 407ms/step - loss: 0.3355 - accuracy: 0.8786 - val_loss: 1.4187 - val_accuracy: 0.6295
# Epoch 8/30
# 400/400 [==============================] - 166s 414ms/step - loss: 0.3119 - accuracy: 0.8889 - val_loss: 0.4949 - val_accuracy: 0.8315
# Epoch 9/30
# 400/400 [==============================] - 161s 403ms/step - loss: 0.2697 - accuracy: 0.9050 - val_loss: 1.0722 - val_accuracy: 0.6860
# Epoch 10/30
# 400/400 [==============================] - 164s 410ms/step - loss: 0.2500 - accuracy: 0.9100 - val_loss: 0.6513 - val_accuracy: 0.8060
# Epoch 11/30
# 400/400 [==============================] - 162s 406ms/step - loss: 0.2292 - accuracy: 0.9202 - val_loss: 0.5226 - val_accuracy: 0.8320
# Epoch 12/30
# 400/400 [==============================] - 162s 406ms/step - loss: 0.2001 - accuracy: 0.9293 - val_loss: 0.5579 - val_accuracy: 0.8365
# Epoch 13/30
# 400/400 [==============================] - 159s 397ms/step - loss: 0.2036 - accuracy: 0.9300 - val_loss: 1.8949 - val_accuracy: 0.6440
# Epoch 14/30
# 400/400 [==============================] - 162s 404ms/step - loss: 0.1732 - accuracy: 0.9420 - val_loss: 0.7880 - val_accuracy: 0.7730
# Epoch 15/30
# 400/400 [==============================] - 159s 397ms/step - loss: 0.1822 - accuracy: 0.9376 - val_loss: 0.2804 - val_accuracy: 0.8965
# Epoch 16/30
# 400/400 [==============================] - 165s 411ms/step - loss: 0.1526 - accuracy: 0.9455 - val_loss: 0.1292 - val_accuracy: 0.9575
# Epoch 17/30
# 400/400 [==============================] - 161s 401ms/step - loss: 0.1546 - accuracy: 0.9481 - val_loss: 2.3277 - val_accuracy: 0.6180
# Epoch 18/30
# 400/400 [==============================] - 162s 406ms/step - loss: 0.1381 - accuracy: 0.9526 - val_loss: 0.4587 - val_accuracy: 0.8625
# Epoch 19/30
# 400/400 [==============================] - 161s 403ms/step - loss: 0.1252 - accuracy: 0.9581 - val_loss: 2.6638 - val_accuracy: 0.5470
# Epoch 20/30
# 400/400 [==============================] - 159s 398ms/step - loss: 0.1194 - accuracy: 0.9564 - val_loss: 0.3547 - val_accuracy: 0.9055
# Epoch 21/30
# 400/400 [==============================] - 162s 404ms/step - loss: 0.1247 - accuracy: 0.9538 - val_loss: 0.2160 - val_accuracy: 0.9380
# Epoch 22/30
# 400/400 [==============================] - 160s 399ms/step - loss: 0.1166 - accuracy: 0.9625 - val_loss: 0.1684 - val_accuracy: 0.9460
# Epoch 23/30
# 400/400 [==============================] - 160s 399ms/step - loss: 0.1056 - accuracy: 0.9619 - val_loss: 0.1917 - val_accuracy: 0.9380
# Epoch 24/30
# 400/400 [==============================] - 163s 407ms/step - loss: 0.1031 - accuracy: 0.9647 - val_loss: 0.1482 - val_accuracy: 0.9510
# Epoch 25/30
# 400/400 [==============================] - 162s 404ms/step - loss: 0.1061 - accuracy: 0.9660 - val_loss: 0.0958 - val_accuracy: 0.9645
# Epoch 26/30
# 400/400 [==============================] - 161s 403ms/step - loss: 0.0944 - accuracy: 0.9665 - val_loss: 0.4195 - val_accuracy: 0.8480
# Epoch 27/30
# 400/400 [==============================] - 160s 399ms/step - loss: 0.1001 - accuracy: 0.9657 - val_loss: 0.2582 - val_accuracy: 0.9180
# Epoch 28/30
# 400/400 [==============================] - 160s 400ms/step - loss: 0.0895 - accuracy: 0.9700 - val_loss: 0.1273 - val_accuracy: 0.9610
# Epoch 29/30
# 400/400 [==============================] - 167s 416ms/step - loss: 0.0769 - accuracy: 0.9753 - val_loss: 0.0808 - val_accuracy: 0.9810
# Epoch 30/30
# 400/400 [==============================] - 165s 411ms/step - loss: 0.0800 - accuracy: 0.9725 - val_loss: 0.1726 - val_accuracy: 0.9485

# %%
# Plot training accuracy graph
epochs = range(1, num_epoch + 1)
train_acc = model.history.history['accuracy']  # Use 'accuracy' instead of 'acc'
plt.plot(epochs, train_acc, 'b', label='Training Accuracy')
plt.title('Training Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

# Plot validation accuracy graph
val_acc = model.history.history['val_accuracy']  # Use 'val_accuracy' instead of 'val_acc'
plt.plot(epochs, val_acc, 'r', label='Validation Accuracy')
plt.title('Validation Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

# Plot training and validation accuracy graph together
plt.plot(epochs, train_acc, 'b', label='Training Accuracy')
plt.plot(epochs, val_acc, 'r', label='Validation Accuracy')
plt.title('Training and Validation Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

# %%
import matplotlib.pyplot as plt
import matplotlib.font_manager as fm
from matplotlib.font_manager import FontProperties
import numpy as np
import matplotlib.pyplot as plt
from sklearn.metrics import accuracy_score, f1_score, confusion_matrix
import itertools  # Import itertools module

# Generate predictions
y_train_pred = model.predict(train_generator)
y_val_pred = model.predict(validation_generator)

# Get true labels
y_train_true = train_generator.classes
y_val_true = validation_generator.classes

# Calculate accuracy
val_accuracy = accuracy_score(y_val_true, np.argmax(y_val_pred, axis=1))

# Calculate F1 score
train_f1_score = f1_score(y_train_true, np.argmax(y_train_pred, axis=1), average='weighted')
val_f1_score = f1_score(y_val_true, np.argmax(y_val_pred, axis=1), average='weighted')

print("Validation Accuracy: {:.2f}%".format(val_accuracy * 100))
print("Validation F1 Score: {:.2f}".format(val_f1_score))
# Out:
# 400/400 [==============================] - 134s 330ms/step
# 100/100 [==============================] - 8s 78ms/step
# Validation Accuracy: 94.85%
# Validation F1 Score: 0.95

# %%
# Confusion matrix
val_cm = confusion_matrix(y_val_true, np.argmax(y_val_pred, axis=1))

# Plot confusion matrix
def plot_confusion_matrix(cm, classes, normalize=False, title='Confusion matrix', cmap=plt.cm.BuGn):
    """
    This function prints and plots the confusion matrix.
    Normalization can be applied by setting `normalize=True`.
    """
    plt.figure(figsize=(6, 6))
    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation=45)
    plt.yticks(tick_marks, classes)

    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
        print("Normalized confusion matrix")
    else:
        print('Confusion matrix, without normalization')

    print(cm)

    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, cm[i, j],
                 horizontalalignment="center",
                 color="white" if cm[i, j] > thresh else "black")
    plt.tight_layout()
    plt.ylabel('True label')
    plt.xlabel('Predicted label')
    plt.tight_layout()

class_names = train_generator.class_indices.keys()
plot_confusion_matrix(val_cm, classes=class_names, title='Validation Confusion Matrix')
# Out:
# Confusion matrix, without normalization
# [[442   6   4  48]
#  [  7 457  16  20]
#  [  0   0 500   0]
#  [  0   2   0 498]]

# %%
import seaborn as sns
#  "Accuracy"
plt.figure(figsize=[8, 4])
sns.set_theme()
plt.plot(history.history['accuracy'], 'o-', color="Green")
plt.plot(history.history['val_accuracy'] , 'o-', color="Red")
plt.title('Model Accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='lower right')
#plt.show()
plt.gca().set_position([0.1, 0.12, 0.8, 0.8])
# "Loss"
plt.figure(figsize=[8, 4])
sns.set_theme()
plt.plot(history.history['loss'], 'o-', color="Green")
plt.plot(history.history['val_loss'], 'o-', color="Red")
plt.title('Model Loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper right')
#plt.show()
plt.gca().set_position([0.1, 0.12, 0.8, 0.8])
